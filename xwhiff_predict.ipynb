# %%
# XWhiff Model Training and Prediction
# This notebook develops and optimizes an XGBoost model to predict swing-and-miss probability
# 
# Import necessary libraries for model development and optimization
import pandas as pd                      # Data manipulation and analysis
import numpy as np                       # Numerical operations
import xgboost as xgb                    # Gradient boosting framework
from xgboost import XGBClassifier        # XGBoost classifier for binary classification
from sklearn.linear_model import LogisticRegression  # Alternative linear model
import matplotlib.pyplot as plt          # Basic plotting functionality
import seaborn as sns                    # Statistical data visualization
import sklearn                           # Machine learning library
from sklearn.model_selection import KFold  # Cross-validation functionality
from sklearn.metrics import log_loss     # Evaluation metric for binary classification
import optuna                            # Hyperparameter optimization framework

# %%
# Load cleaned pitch tracking data from multiple seasons
# This provides a comprehensive dataset spanning multiple years for robust model training
clean_2024 = pd.read_csv('./whiff_csvs/2024_whiff_clean.csv', low_memory=False)  # Test data
clean_2023 = pd.read_csv('./whiff_csvs/2023_whiff_clean.csv', low_memory=False)  # Training data
clean_2022 = pd.read_csv('./whiff_csvs/2022_whiff_clean.csv', low_memory=False)  # Training data

# %%
# Note: Remove any commented code blocks that are no longer needed
# This keeps the notebook clean and focused on the current methodology

# %%
clean_2022.head()
# Out:
#   PitcherThrows BatterSide  Outs  Balls  Strikes TaggedPitchType  \
# 0         Right      Right     0      0        0        Fastball
# 1         Right      Right     0      1        0        Fastball
# 2         Right      Right     0      2        0        Fastball
# 3         Right      Right     0      2        1        Fastball
# 4         Right      Right     0      2        2        Fastball
#
#       PitchCall  RelSpeed  VertRelAngle  HorzRelAngle  ...  Extension  \
# 0    BallCalled  91.80411     -3.816351     -3.522621  ...    5.74749
# 1    BallCalled  92.38028     -3.537349     -3.658209  ...    5.55677
# 2  StrikeCalled  92.75261     -3.209314     -2.573778  ...    5.49731
# 3      FoulBall  92.35726     -2.446575     -2.958796  ...    5.58153
# 4        InPlay  94.60763     -3.377392     -2.749154  ...    5.70240
#
#    InducedVertBreak  HorzBreak  PlateLocHeight  PlateLocSide  VertApprAngle  \
# 0          18.08218   12.78119         1.16387      -0.26392      -6.801089
# 1          16.22639   14.28202         1.28412      -0.42104      -6.825532
# 2          17.84517   12.29304         1.84823       0.54753      -6.174757
# 3          19.67907   10.39461         2.68124       0.10833      -5.096501
# 4          17.33721   14.15202         1.78420       0.58484      -6.062640
#
#    HorzApprAngle     PitcherId  whiff  count
# 0      -1.239948  1.000074e+09      0    0-0
# 1      -1.116474  1.000074e+09      0    1-0
# 2      -0.385627  1.000074e+09      0    2-0
# 3      -1.107350  1.000074e+09      0    2-1
# 4      -0.220896  1.000074e+09      0    2-2
#
# [5 rows x 24 columns]

# %%
clean_2023.head()
# Out:
#   PitcherThrows BatterSide  Outs  Balls  Strikes TaggedPitchType  \
# 0         Right       Left     0      0        0        Fastball
# 1         Right       Left     0      0        0        ChangeUp
# 2         Right       Left     0      0        1        Fastball
# 3         Right       Left     0      1        1       Curveball
# 4         Right       Left     0      2        1        ChangeUp
#
#       PitchCall  RelSpeed  VertRelAngle  HorzRelAngle  ...  RelSide  \
# 0        InPlay  88.43126     -3.720299     -0.585480  ...  0.59849
# 1  StrikeCalled  80.24299     -0.945260     -1.525434  ...  0.71170
# 2    BallCalled  87.42133     -3.303045     -0.520038  ...  0.69940
# 3    BallCalled  72.85011     -1.028297      0.347481  ...  0.30630
# 4        InPlay  82.40725     -2.265863     -1.333121  ...  0.72582
#
#    Extension  InducedVertBreak  HorzBreak  PlateLocHeight  PlateLocSide  \
# 0    5.88136          23.19308   10.90638         1.91630       0.96361
# 1    6.53191          11.33949   11.80068         2.80934       0.29542
# 2    5.79229          21.80682   10.33725         2.09101       1.07706
# 3    5.85791         -10.56816  -17.28883         0.22062      -0.81158
# 4    6.82618          12.77918   13.40245         1.81788       0.62639
#
#    VertApprAngle  HorzApprAngle  whiff  count
# 0      -6.304004       1.371603      0    0-0
# 1      -6.900707       0.619730      0    0-0
# 2      -6.285148       1.332128      0    0-1
# 3     -12.684304      -2.772901      0    1-1
# 4      -7.448031       1.117945      0    2-1
#
# [5 rows x 23 columns]

# %%
clean_2024.head()
# Out:
#   PitcherThrows BatterSide  Outs  Balls  Strikes TaggedPitchType  \
# 0         Right      Right     0      0        0          Slider
# 1         Right      Right     0      1        0        Fastball
# 2         Right      Right     0      1        1        Fastball
# 3         Right      Right     0      1        2          Slider
# 4         Right      Right     0      1        2          Slider
#
#               PitchCall  RelSpeed  VertRelAngle  HorzRelAngle  ...  Extension  \
# 0            BallCalled  86.34831     -5.087035     -0.556059  ...    5.20061
# 1          StrikeCalled  94.49974     -3.133086     -0.492520  ...    5.83655
# 2  FoulBallNotFieldable  94.81021     -3.910073     -1.135525  ...    5.67326
# 3  FoulBallNotFieldable  86.30865     -1.385858     -0.791508  ...    5.43599
# 4            BallCalled  87.45870     -4.605749     -1.323250  ...    5.28786
#
#    InducedVertBreak  HorzBreak  PlateLocHeight  PlateLocSide  VertApprAngle  \
# 0          -1.26150   -6.71201        -1.24052      -0.79734     -12.231122
# 1          20.20828    3.49654         3.00046       0.29788      -5.365324
# 2          22.06875   -0.43740         2.48669      -0.87744      -5.815582
# 3           2.34610   -6.38485         2.69703      -1.15108      -7.862841
# 4           0.27646   -4.37162        -0.43496      -1.44974     -11.264591
#
#    HorzApprAngle     PitcherId  whiff  count
# 0      -1.751516  1.000234e+09      0    0-0
# 1       0.134391  1.000234e+09      0    1-0
# 2      -1.213668  1.000234e+09      0    1-1
# 3      -1.929632  1.000234e+09      0    1-2
# 4      -2.102031  1.000234e+09      0    1-2
#
# [5 rows x 24 columns]

# %%
# Create train/test split using temporal separation
# 2024 data as test set provides realistic out-of-time validation
# 2022-2023 combined data provides sufficient training samples
test = clean_2024.copy()
train = pd.concat([clean_2023.copy(), clean_2022.copy()])

# %% [markdown]
# # Model Development Strategy
#
# ## Feature Selection Objectives
# The primary goals of this analysis are:
# 1. **Feature Selection**: Identify which pitch characteristics are most predictive of swing-and-miss outcomes
# 2. **Model Architecture**: Determine if pitch-type-specific models outperform a unified model
# 3. **Temporal Validation**: Use 2022-2023 data for training and 2024 for testing to ensure robust performance
#
# ## Pitch Type Segmentation Considerations
# While grouping pitches by type (fastball, breaking ball, offspeed) seems logical due to similar movement profiles, several challenges exist:
#
# ### Data Quality Challenges
# - **Subjective Tagging**: Pitch classification relies on human judgment, leading to inconsistencies
# - **Operator Variability**: Different taggers may classify similar pitches differently
# - **Edge Cases**: Borderline pitches (e.g., hard slider vs. cutter) are particularly prone to misclassification
#
# ### Cleaning Limitations
# Automated pitch type correction is difficult because:
# - Pitch types exist on a spectrum rather than discrete categories
# - Movement parameters can overlap significantly between pitch types
# - Contextual factors (game situation, pitcher intent) influence classification
#
# ## Methodology
# - **Training Data**: Combined 2022-2023 seasons for maximum sample size
# - **Test Data**: 2024 season for out-of-time validation
# - **Evaluation**: Compare unified model vs. pitch-type-specific models using cross-validation

# %%
# Examine data types in the combined training dataset
# This helps identify any type inconsistencies between seasons that need addressing
train.dtypes
# Out:
# PitcherThrows        object
# BatterSide           object
# Outs                  int64
# Balls                 int64
# Strikes               int64
# TaggedPitchType      object
# PitchCall            object
# RelSpeed            float64
# VertRelAngle        float64
# HorzRelAngle        float64
# SpinRate            float64
# SpinAxis            float64
# RelHeight           float64
# RelSide             float64
# Extension           float64
# InducedVertBreak    float64
# HorzBreak           float64
# PlateLocHeight      float64
# PlateLocSide        float64
# VertApprAngle       float64
# HorzApprAngle       float64
# whiff                 int64
# count                object
# PitcherId           float64
# dtype: object

# %%
# Convert categorical variables to proper data types for XGBoost
# XGBoost with enable_categorical=True can handle categorical features more efficiently
# This ensures handedness variables are treated as discrete categories, not ordinal
train['PitcherThrows'] = train['PitcherThrows'].astype('category')
train['BatterSide'] = train['BatterSide'].astype('category')
test['PitcherThrows'] = test['PitcherThrows'].astype('category')
test['BatterSide'] = test['BatterSide'].astype('category')

# %%
# Function to extract features and target variable from dataset
# This standardizes the feature selection process across different data splits
def split(df):
    """
    Extract features and target variable for model training/testing
    
    Features include:
    - Game situation: PitcherThrows, BatterSide, Outs, Balls, Strikes
    - Pitch characteristics: RelSpeed, VertRelAngle, HorzRelAngle, SpinRate, SpinAxis
    - Release point: RelHeight, RelSide, Extension
    - Movement: InducedVertBreak, HorzBreak
    - Location: PlateLocHeight, PlateLocSide, VertApprAngle, HorzApprAngle
    """
    X = df[['PitcherThrows', 'BatterSide', 'Outs', 'Balls', 'Strikes',
            'RelSpeed', 'VertRelAngle', 'HorzRelAngle', 'SpinRate', 'SpinAxis',
            'RelHeight', 'RelSide', 'Extension', 'InducedVertBreak', 'HorzBreak',
            'PlateLocHeight', 'PlateLocSide', 'VertApprAngle', 'HorzApprAngle']]
    y = df['whiff']
    return X, y

# Apply feature extraction to both training and test sets
X_train, y_train = split(train)
X_test, y_test = split(test)

# %%
# Cross-validation function to evaluate model performance
# Uses 5-fold CV with log loss metric for binary classification evaluation
def CV(X_train, Y_train):
    """
    Perform 5-fold cross-validation to estimate model performance
    
    Args:
        X_train: Feature matrix
        Y_train: Target variable (binary: whiff/no-whiff)
    
    Returns:
        Mean log loss across all folds (lower is better)
    """
    model = XGBClassifier(enable_categorical=True)  # Enable categorical feature handling
    kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-fold CV with shuffling
    validation_errors = np.empty(0)

    for train_idx, valid_idx in kf.split(X_train):
        # Split data for this fold
        split_X_train, split_X_valid = X_train.iloc[train_idx, :], X_train.iloc[valid_idx, :]
        split_Y_train, split_Y_valid = Y_train.iloc[train_idx], Y_train.iloc[valid_idx] 
        
        # Train model on training fold
        model.fit(split_X_train, split_Y_train)
        
        # Predict probabilities on validation fold
        Y_pred = model.predict_proba(split_X_valid)[:, 1]  # Probability of whiff (class 1)
        
        # Calculate log loss for this fold
        validation_errors = np.append(validation_errors, log_loss(split_Y_valid, Y_pred))
    
    return np.mean(validation_errors)

# %%
# Calculate baseline cross-validation error using all features
# This establishes our benchmark performance before feature selection
CV_errors = pd.DataFrame({'cv_error': np.array(CV(X_train, y_train))}, index=[0])
CV_errors
# Out:
#    cv_error
# 0  0.288938

# %%
# Initialize dataframe to store individual feature performance
# This will help us understand the predictive power of each feature independently
feature_errors = pd.DataFrame({"feature_name": X_train.columns})
feature_errors
# Out:
#         feature_name
# 0      PitcherThrows
# 1         BatterSide
# 2               Outs
# 3              Balls
# 4            Strikes
# 5           RelSpeed
# 6       VertRelAngle
# 7       HorzRelAngle
# 8           SpinRate
# 9           SpinAxis
# 10         RelHeight
# 11           RelSide
# 12         Extension
# 13  InducedVertBreak
# 14         HorzBreak
# 15    PlateLocHeight
# 16      PlateLocSide
# 17     VertApprAngle
# 18     HorzApprAngle

# %%
# Evaluate individual feature performance using single-feature models
# This identifies which features have the strongest independent predictive power
def feature_error(X_train, Y_train):
    """
    Test each feature individually to assess its predictive power
    
    Args:
        X_train: Full feature matrix
        Y_train: Target variable
    
    Returns:
        DataFrame with feature names and their individual CV errors
    """
    feature_errors = pd.DataFrame({"feature_name": X_train.columns})
    model = XGBClassifier(enable_categorical=True)
    feature_error = np.empty(0)

    # Test each feature individually
    for x_var in X_train.columns:
        print(f"Testing feature: {x_var}")
        
        # Create single-feature dataset
        X = X_train[[x_var]]
       
        kf = KFold(n_splits=5, shuffle=True, random_state=42)
        validation_errors = np.empty(0)

        # Cross-validate single-feature model
        for train_idx, valid_idx in kf.split(X_train):
            split_X_train, split_X_valid = X.iloc[train_idx, :], X.iloc[valid_idx, :]
            split_Y_train, split_Y_valid = Y_train.iloc[train_idx], Y_train.iloc[valid_idx] 
            
            model.fit(split_X_train, split_Y_train)
            Y_pred = model.predict_proba(split_X_valid)[:, 1]
            validation_errors = np.append(validation_errors, log_loss(split_Y_valid, Y_pred))
        
        # Store mean error for this feature
        feature_error = np.append(feature_error, np.mean(validation_errors))
    
    feature_errors['error'] = feature_error
    return feature_errors

# Execute feature importance analysis
errors = feature_error(X_train, y_train)
errors
# Out:
# Testing feature: PitcherThrows
# Testing feature: BatterSide
# Testing feature: Outs
# Testing feature: Balls
# Testing feature: Strikes
# Testing feature: RelSpeed
# Testing feature: VertRelAngle
# Testing feature: HorzRelAngle
# Testing feature: SpinRate
# Testing feature: SpinAxis
# Testing feature: RelHeight
# Testing feature: RelSide
# Testing feature: Extension
# Testing feature: InducedVertBreak
# Testing feature: HorzBreak
# Testing feature: PlateLocHeight
# Testing feature: PlateLocSide
# Testing feature: VertApprAngle
# Testing feature: HorzApprAngle
#         feature_name     error
# 0      PitcherThrows  0.334504
# 1         BatterSide  0.334452
# 2               Outs  0.334341
# 3              Balls  0.333845
# 4            Strikes  0.330366
# 5           RelSpeed  0.331845
# 6       VertRelAngle  0.328793
# 7       HorzRelAngle  0.331157
# 8           SpinRate  0.332835
# 9           SpinAxis  0.332997
# 10         RelHeight  0.334529
# 11           RelSide  0.334552
# 12         Extension  0.334498
# 13  InducedVertBreak  0.332046
# 14         HorzBreak  0.333558
# 15    PlateLocHeight  0.329106
# 16      PlateLocSide  0.329300
# 17     VertApprAngle  0.327750
# 18     HorzApprAngle  0.333257

# %%
feature_errors = errors.copy()

# %%
# Rank features by their individual predictive power (lowest error = best feature)
# This creates an ordered list from most to least important features
feature_importance = feature_errors.sort_values(by="error")["feature_name"]
feature_importance
# Out:
# 17       VertApprAngle
# 6         VertRelAngle
# 15      PlateLocHeight
# 16        PlateLocSide
# 4              Strikes
# 7         HorzRelAngle
# 5             RelSpeed
# 13    InducedVertBreak
# 8             SpinRate
# 9             SpinAxis
# 18       HorzApprAngle
# 14           HorzBreak
# 3                Balls
# 2                 Outs
# 1           BatterSide
# 12           Extension
# 0        PitcherThrows
# 10           RelHeight
# 11             RelSide
# Name: feature_name, dtype: object

# %%
# Forward feature selection: incrementally add features in order of importance
# This finds the optimal number of features by testing cumulative feature sets
def best_features(X_train, Y_train, feature_importance):
    """
    Perform forward feature selection using ranked feature importance
    
    Starting with the best individual feature, iteratively add the next best feature
    and evaluate performance until we find the optimal feature subset
    
    Args:
        X_train: Training features
        Y_train: Training target
        feature_importance: Features ranked by individual performance
    
    Returns:
        predictors: List of feature subsets tested
        feature_error: CV error for each feature subset
    """
    model = XGBClassifier(enable_categorical=True)
    feature_error = np.empty(0)
    predictors = []

    # Test each cumulative feature subset
    for i in np.arange(0, len(feature_importance)):
        print(f"Testing {i+1} features...")
        
        # Select top i+1 features
        X = X_train[np.array(feature_importance[0:i+1])]
        predictors.append(feature_importance[0:i+1].values)
    
        kf = KFold(n_splits=5, shuffle=True, random_state=42)
        validation_errors = np.empty(0)

        # Cross-validate this feature subset
        for train_idx, valid_idx in kf.split(X_train):
            split_X_train, split_X_valid = X.iloc[train_idx, :], X.iloc[valid_idx, :]
            split_Y_train, split_Y_valid = Y_train.iloc[train_idx], Y_train.iloc[valid_idx] 
            
            model.fit(split_X_train, split_Y_train)
            Y_pred = model.predict_proba(split_X_valid)[:, 1]
            validation_errors = np.append(validation_errors, log_loss(split_Y_valid, Y_pred))
        
        feature_error = np.append(feature_error, np.mean(validation_errors))
    
    return predictors, feature_error

# %%
# Execute forward feature selection to find optimal feature combination
# This process will test all cumulative feature subsets and find the best performing one
predictors, predict_error = best_features(X_train, y_train, feature_importance)
x_vars_errors = pd.DataFrame({"subset": predictors, "validation error": predict_error})
# Out:
# Testing 1 features...
# Testing 2 features...
# Testing 3 features...
# Testing 4 features...
# Testing 5 features...
# Testing 6 features...
# Testing 7 features...
# Testing 8 features...
# Testing 9 features...
# Testing 10 features...
# Testing 11 features...
# Testing 12 features...
# Testing 13 features...
# Testing 14 features...
# Testing 15 features...
# Testing 16 features...
# Testing 17 features...
# Testing 18 features...
# Testing 19 features...

# %%
# Identify the optimal feature subset with lowest validation error
# This represents the best balance between model complexity and performance
feature = pd.DataFrame({"subset": predictors, "validation error": predict_error})
new_X_train_columns = feature.sort_values(by='validation error').iloc[0, 0]

# Note: Features like Extension, RelHeight, RelSide may be dropped if they don't improve performance
# This suggests these release point characteristics are less predictive than other features
new_X_train_columns
# Out:
# array(['VertApprAngle', 'VertRelAngle', 'PlateLocHeight', 'PlateLocSide',
#        'Strikes', 'HorzRelAngle', 'RelSpeed', 'InducedVertBreak',
#        'SpinRate', 'SpinAxis', 'HorzApprAngle', 'HorzBreak', 'Balls',
#        'Outs', 'BatterSide', 'Extension', 'PitcherThrows', 'RelHeight'],
#       dtype=object)

# %% [markdown]
# # Pitch Type-Specific Model Analysis
#
# Now we'll test whether separating pitches into distinct categories improves model performance. The hypothesis is that different pitch types (fastballs vs. breaking balls vs. offspeed) have fundamentally different characteristics that make swing-and-miss prediction, and specialized models might capture these nuances better than a unified approach.
#
# ## Approach
# We'll repeat the same feature selection process for three pitch categories:
# 1. **Fastballs**: Fastball, Sinker
# 2. **Breaking Balls**: Curveball, Cutter, Slider
# 3. **Offspeed**: ChangeUp
#
# This will allow us to compare:
# - **Unified Model**: Single model trained on all pitch types
# - **Specialized Models**: Separate models for each pitch category
# - **Feature Importance**: Whether different features matter for different pitch types

# %%
# Split datasets by pitch type categories for specialized model training
# Each category has different characteristics that may benefit from specialized modeling

# Fastball category: High velocity, minimal movement
FB_train = train[(train['TaggedPitchType'] == 'Fastball') | (train['TaggedPitchType'] == 'Sinker')]
FB_test = test[(test['TaggedPitchType'] == 'Fastball') | (test['TaggedPitchType'] == 'Sinker')]

# Breaking ball category: Significant movement, spin-dependent
BB_train = train[(train['TaggedPitchType'] == 'Curveball') | (train['TaggedPitchType'] == 'Cutter') | (train['TaggedPitchType'] == 'Slider')]
BB_test = test[(test['TaggedPitchType'] == 'Curveball') | (test['TaggedPitchType'] == 'Slider') | (test['TaggedPitchType'] == 'Cutter')]

# Offspeed category: Deception-based, velocity differential
OFF_train = train[(train['TaggedPitchType'] == 'ChangeUp')]
OFF_test = test[(test['TaggedPitchType'] == 'ChangeUp')]

# %% [markdown]
# # Cutter Classification Decision
#
# ## Initial Approach vs. Final Decision
# **Initial Classification**: Cutter grouped with fastballs due to velocity similarity (essentially opposite of sinker movement)
#
# **Final Classification**: Cutter moved to breaking ball category, though in the MLB cutters are often thought of and are thrown like Fastballs. In college baseball cutters are more commonly thrown as a breaking pitch similar to a Slider
#
# ## Reasoning for Change
# 1. **Movement Profile**: Despite velocity similarity to fastballs, cutters have movement characteristics closer to sliders
# 2. **Tagging Consistency**: Cutters are frequently mistagged as sliders during games due to visual similarity
# 3. **Performance Impact**: Moving cutters to the breaking ball category reduced log loss for both:
#    - Fastball models (more homogeneous group)
#    - Breaking ball models (better handles cutter-slider similarity)
#
# ## Key Insight
# This demonstrates how data quality issues (subjective pitch tagging) can inform modeling decisions. Sometimes grouping by observed characteristics (how pitches are actually classified) performs better than grouping by theoretical characteristics (how pitches should be classified).

# %%
FB_X_train, FB_y_train = split(FB_train)
FB_X_test, FB_y_test = split(FB_test)
BB_X_train, BB_y_train = split(BB_train)
BB_X_test, BB_X_test = split(BB_test)
OFF_X_train, OFF_y_train = split(OFF_train)
OFF_X_test, OFF_y_test = split(OFF_test)

# %%
#cv_errors feature_errors x_vars_errors
FB_CV = CV(FB_X_train,FB_y_train)
CV_errors['FB_CV_error'] = [FB_CV]
BB_CV = CV(BB_X_train,BB_y_train)
CV_errors['BB_CV_error'] = [BB_CV]
OFF_CV = CV(OFF_X_train,OFF_y_train)
CV_errors['OFF_CV_error'] = [OFF_CV]

# %%
CV_errors
# Out:
#    cv_error  FB_CV_error  BB_CV_error  OFF_CV_error
# 0  0.288938     0.246319     0.333187      0.377133

# %%
FB_feature_error = feature_error(FB_X_train,FB_y_train)
BB_feature_error = feature_error(BB_X_train,BB_y_train)
OFF_feature_error = feature_error(OFF_X_train,OFF_y_train)
# Out:
# Testing feature: PitcherThrows
# Testing feature: BatterSide
# Testing feature: Outs
# Testing feature: Balls
# Testing feature: Strikes
# Testing feature: RelSpeed
# Testing feature: VertRelAngle
# Testing feature: HorzRelAngle
# Testing feature: SpinRate
# Testing feature: SpinAxis
# Testing feature: RelHeight
# Testing feature: RelSide
# Testing feature: Extension
# Testing feature: InducedVertBreak
# Testing feature: HorzBreak
# Testing feature: PlateLocHeight
# Testing feature: PlateLocSide
# Testing feature: VertApprAngle
# Testing feature: HorzApprAngle
# Testing feature: PitcherThrows
# Testing feature: BatterSide
# Testing feature: Outs
# Testing feature: Balls
# Testing feature: Strikes
# Testing feature: RelSpeed
# Testing feature: VertRelAngle
# Testing feature: HorzRelAngle
# Testing feature: SpinRate
# Testing feature: SpinAxis
# Testing feature: RelHeight
# Testing feature: RelSide
# Testing feature: Extension
# Testing feature: InducedVertBreak
# Testing feature: HorzBreak
# Testing feature: PlateLocHeight
# Testing feature: PlateLocSide
# Testing feature: VertApprAngle
# Testing feature: HorzApprAngle
# Testing feature: PitcherThrows
# Testing feature: BatterSide
# Testing feature: Outs
# Testing feature: Balls
# Testing feature: Strikes
# Testing feature: RelSpeed
# Testing feature: VertRelAngle
# Testing feature: HorzRelAngle
# Testing feature: SpinRate
# Testing feature: SpinAxis
# Testing feature: RelHeight
# Testing feature: RelSide
# Testing feature: Extension
# Testing feature: InducedVertBreak
# Testing feature: HorzBreak
# Testing feature: PlateLocHeight
# Testing feature: PlateLocSide
# Testing feature: VertApprAngle
# Testing feature: HorzApprAngle

# %%
FB_feature_error, BB_feature_error, OFF_feature_error
# Out:
# (        feature_name     error
#  0      PitcherThrows  0.281790
#  1         BatterSide  0.281784
#  2               Outs  0.281668
#  3              Balls  0.281251
#  4            Strikes  0.278381
#  5           RelSpeed  0.280399
#  6       VertRelAngle  0.279136
#  7       HorzRelAngle  0.279372
#  8           SpinRate  0.281089
#  9           SpinAxis  0.280898
#  10         RelHeight  0.281904
#  11           RelSide  0.281883
#  12         Extension  0.281864
#  13  InducedVertBreak  0.279845
#  14         HorzBreak  0.281534
#  15    PlateLocHeight  0.273594
#  16      PlateLocSide  0.275998
#  17     VertApprAngle  0.274536
#  18     HorzApprAngle  0.280868,
#          feature_name     error
#  0      PitcherThrows  0.385154
#  1         BatterSide  0.385074
#  2               Outs  0.385115
#  3              Balls  0.384098
#  4            Strikes  0.380252
#  5           RelSpeed  0.380534
#  6       VertRelAngle  0.369073
#  7       HorzRelAngle  0.379287
#  8           SpinRate  0.384332
#  9           SpinAxis  0.384567
#  10         RelHeight  0.385332
#  11           RelSide  0.385367
#  12         Extension  0.385180
#  13  InducedVertBreak  0.384332
#  14         HorzBreak  0.384742
#  15    PlateLocHeight  0.364224
#  16      PlateLocSide  0.377611
#  17     VertApprAngle  0.382221
#  18     HorzApprAngle  0.381948,
#          feature_name     error
#  0      PitcherThrows  0.428619
#  1         BatterSide  0.428531
#  2               Outs  0.428580
#  3              Balls  0.427514
#  4            Strikes  0.427551
#  5           RelSpeed  0.429069
#  6       VertRelAngle  0.415164
#  7       HorzRelAngle  0.423157
#  8           SpinRate  0.429103
#  9           SpinAxis  0.428640
#  10         RelHeight  0.428551
#  11           RelSide  0.428938
#  12         Extension  0.429294
#  13  InducedVertBreak  0.429040
#  14         HorzBreak  0.428259
#  15    PlateLocHeight  0.405693
#  16      PlateLocSide  0.415849
#  17     VertApprAngle  0.417739
#  18     HorzApprAngle  0.425861)

# %%
FB_feature_importance = FB_feature_error.sort_values(by="error")["feature_name"]
BB_feature_importance = BB_feature_error.sort_values(by="error")["feature_name"]
OFF_feature_importance = OFF_feature_error.sort_values(by="error")["feature_name"]

# %%
FB_x_vars, FB_best_features = best_features(FB_X_train, FB_y_train,FB_feature_importance)
BB_x_vars, BB_best_features = best_features(BB_X_train, BB_y_train,BB_feature_importance)
OFF_x_vars, OFF_best_features = best_features(OFF_X_train, OFF_y_train,OFF_feature_importance)
# Out:
# Testing 1 features...
# Testing 2 features...
# Testing 3 features...
# Testing 4 features...
# Testing 5 features...
# Testing 6 features...
# Testing 7 features...
# Testing 8 features...
# Testing 9 features...
# Testing 10 features...
# Testing 11 features...
# Testing 12 features...
# Testing 13 features...
# Testing 14 features...
# Testing 15 features...
# Testing 16 features...
# Testing 17 features...
# Testing 18 features...
# Testing 19 features...
# Testing 1 features...
# Testing 2 features...
# Testing 3 features...
# Testing 4 features...
# Testing 5 features...
# Testing 6 features...
# Testing 7 features...
# Testing 8 features...
# Testing 9 features...
# Testing 10 features...
# Testing 11 features...
# Testing 12 features...
# Testing 13 features...
# Testing 14 features...
# Testing 15 features...
# Testing 16 features...
# Testing 17 features...
# Testing 18 features...
# Testing 19 features...
# Testing 1 features...
# Testing 2 features...
# Testing 3 features...
# Testing 4 features...
# Testing 5 features...
# Testing 6 features...
# Testing 7 features...
# Testing 8 features...
# Testing 9 features...
# Testing 10 features...
# Testing 11 features...
# Testing 12 features...
# Testing 13 features...
# Testing 14 features...
# Testing 15 features...
# Testing 16 features...
# Testing 17 features...
# Testing 18 features...
# Testing 19 features...

# %%
feature['FB_x_vars'] = FB_x_vars
feature['FB_error'] = FB_best_features
feature['BB_x_vars'] = BB_x_vars
feature['BB_error'] = BB_best_features
feature['OFF_x_vars'] = OFF_x_vars
feature['OFF_error'] = OFF_best_features

# %%
feature
# Out:
#                                                subset  validation error  \
# 0                                     [VertApprAngle]          0.327750
# 1                       [VertApprAngle, VertRelAngle]          0.317518
# 2       [VertApprAngle, VertRelAngle, PlateLocHeight]          0.311242
# 3   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.303694
# 4   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.298947
# 5   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294956
# 6   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294126
# 7   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.293873
# 8   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.293434
# 9   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291537
# 10  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291180
# 11  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291053
# 12  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290291
# 13  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290158
# 14  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288996
# 15  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288987
# 16  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289002
# 17  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288900
# 18  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288938
#
#                                             FB_x_vars  FB_error  \
# 0                                    [PlateLocHeight]  0.273594
# 1                     [PlateLocHeight, VertApprAngle]  0.269097
# 2       [PlateLocHeight, VertApprAngle, PlateLocSide]  0.261584
# 3   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.257339
# 4   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.254777
# 5   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251720
# 6   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251170
# 7   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251155
# 8   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.249615
# 9   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.249581
# 10  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.249712
# 11  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248544
# 12  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248327
# 13  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248224
# 14  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246190
# 15  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246249
# 16  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246115
# 17  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246091
# 18  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246319
#
#                                             BB_x_vars  BB_error  \
# 0                                    [PlateLocHeight]  0.364224
# 1                      [PlateLocHeight, VertRelAngle]  0.360852
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]  0.352420
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.347815
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.341184
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.339800
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.336998
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334199
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333961
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334161
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333807
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333776
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333514
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333215
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333156
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333168
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333043
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333333
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333188
#
#                                            OFF_x_vars  OFF_error
# 0                                    [PlateLocHeight]   0.405693
# 1                      [PlateLocHeight, VertRelAngle]   0.404867
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]   0.395320
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.392030
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.385797
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.383403
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.381655
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379288
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379334
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378729
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378615
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378463
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378513
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377749
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377982
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377248
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377400
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377226
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377083

# %%
BB_OFF_train = train[(train['TaggedPitchType'] != 'Fastball') & (train['TaggedPitchType'] != 'Sinker')]
BB_OFF_test = test[(test['TaggedPitchType'] != 'Fastball') & (test['TaggedPitchType'] != 'Sinker')]
comb_X_train,comb_y_train = split(BB_OFF_train)
comb_X_test, comb_y_test = split(BB_OFF_test)

# %%
comb_CV = CV(comb_X_train,comb_y_train)
CV_errors['BB_OFF_CV_error'] = [comb_CV]

# %%
CV_errors
# Out:
#    cv_error  FB_CV_error  BB_CV_error  OFF_CV_error  BB_OFF_CV_error
# 0  0.288938     0.246319     0.333187      0.377133         0.344455

# %% [markdown]
# Here I basically determined that despite the fastball error being lower it wasn't worth how much higher the breaking ball and offspeed error were to use these seperate models to train the data. Like I said at the top, I think one of the main reasons that the error of these pitches seperated is higher is because of how subjective pitch tagging is in college baseball.

# %%
comb_feature_error = feature_error(comb_X_train,comb_y_train)
comb_feature_importance = comb_feature_error.sort_values(by="error")["feature_name"]
comb_x_vars, comb_best_features = best_features(comb_X_train, comb_y_train,comb_feature_importance)
feature['comb_x_vars'] = comb_x_vars
feature['comb_error'] = comb_best_features
feature
# Out:
# Testing feature: PitcherThrows
# Testing feature: BatterSide
# Testing feature: Outs
# Testing feature: Balls
# Testing feature: Strikes
# Testing feature: RelSpeed
# Testing feature: VertRelAngle
# Testing feature: HorzRelAngle
# Testing feature: SpinRate
# Testing feature: SpinAxis
# Testing feature: RelHeight
# Testing feature: RelSide
# Testing feature: Extension
# Testing feature: InducedVertBreak
# Testing feature: HorzBreak
# Testing feature: PlateLocHeight
# Testing feature: PlateLocSide
# Testing feature: VertApprAngle
# Testing feature: HorzApprAngle
# Testing 1 features...
# Testing 2 features...
# Testing 3 features...
# Testing 4 features...
# Testing 5 features...
# Testing 6 features...
# Testing 7 features...
# Testing 8 features...
# Testing 9 features...
# Testing 10 features...
# Testing 11 features...
# Testing 12 features...
# Testing 13 features...
# Testing 14 features...
# Testing 15 features...
# Testing 16 features...
# Testing 17 features...
# Testing 18 features...
# Testing 19 features...
#                                                subset  validation error  \
# 0                                     [VertApprAngle]          0.327750
# 1                       [VertApprAngle, VertRelAngle]          0.317518
# 2       [VertApprAngle, VertRelAngle, PlateLocHeight]          0.311242
# 3   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.303694
# 4   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.298947
# 5   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294956
# 6   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294126
# 7   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.293873
# 8   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.293434
# 9   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291537
# 10  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291180
# 11  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291053
# 12  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290291
# 13  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290158
# 14  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288996
# 15  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288987
# 16  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289002
# 17  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288900
# 18  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288938
#
#                                             FB_x_vars  FB_error  \
# 0                                    [PlateLocHeight]  0.273594
# 1                     [PlateLocHeight, VertApprAngle]  0.269097
# 2       [PlateLocHeight, VertApprAngle, PlateLocSide]  0.261584
# 3   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.257339
# 4   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.254777
# 5   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251720
# 6   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251170
# 7   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251155
# 8   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.249615
# 9   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.249581
# 10  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.249712
# 11  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248544
# 12  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248327
# 13  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248224
# 14  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246190
# 15  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246249
# 16  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246115
# 17  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246091
# 18  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246319
#
#                                             BB_x_vars  BB_error  \
# 0                                    [PlateLocHeight]  0.364224
# 1                      [PlateLocHeight, VertRelAngle]  0.360852
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]  0.352420
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.347815
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.341184
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.339800
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.336998
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334199
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333961
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334161
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333807
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333776
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333514
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333215
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333156
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333168
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333043
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333333
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333188
#
#                                            OFF_x_vars  OFF_error  \
# 0                                    [PlateLocHeight]   0.405693
# 1                      [PlateLocHeight, VertRelAngle]   0.404867
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]   0.395320
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.392030
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.385797
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.383403
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.381655
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379288
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379334
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378729
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378615
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378463
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378513
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377749
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377982
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377248
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377400
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377226
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377083
#
#                                           comb_x_vars  comb_error
# 0                                    [PlateLocHeight]    0.376674
# 1                      [PlateLocHeight, VertRelAngle]    0.372859
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]    0.365386
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.359540
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.354040
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.351365
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.349742
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.349522
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345567
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345425
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345448
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345235
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345231
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345168
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345136
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.344700
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.344626
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.344431
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.344459

# %%
feature
# Out:
#                                                subset  validation error  \
# 0                                     [VertApprAngle]          0.327750
# 1                       [VertApprAngle, VertRelAngle]          0.317518
# 2       [VertApprAngle, VertRelAngle, PlateLocHeight]          0.311242
# 3   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.303694
# 4   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.298947
# 5   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294956
# 6   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294126
# 7   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.293873
# 8   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.293434
# 9   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291537
# 10  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291180
# 11  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291053
# 12  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290291
# 13  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290158
# 14  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288996
# 15  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288987
# 16  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289002
# 17  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288900
# 18  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.288938
#
#                                             FB_x_vars  FB_error  \
# 0                                    [PlateLocHeight]  0.273594
# 1                     [PlateLocHeight, VertApprAngle]  0.269097
# 2       [PlateLocHeight, VertApprAngle, PlateLocSide]  0.261584
# 3   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.257339
# 4   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.254777
# 5   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251720
# 6   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251170
# 7   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251155
# 8   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.249615
# 9   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.249581
# 10  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.249712
# 11  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248544
# 12  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248327
# 13  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248224
# 14  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246190
# 15  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246249
# 16  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246115
# 17  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246091
# 18  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246319
#
#                                             BB_x_vars  BB_error  \
# 0                                    [PlateLocHeight]  0.364224
# 1                      [PlateLocHeight, VertRelAngle]  0.360852
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]  0.352420
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.347815
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.341184
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.339800
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.336998
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334199
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333961
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334161
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333807
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333776
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333514
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333215
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333156
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333168
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333043
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333333
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.333188
#
#                                            OFF_x_vars  OFF_error  \
# 0                                    [PlateLocHeight]   0.405693
# 1                      [PlateLocHeight, VertRelAngle]   0.404867
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]   0.395320
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.392030
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.385797
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.383403
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.381655
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379288
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379334
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378729
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378615
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378463
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.378513
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377749
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377982
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377248
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377400
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377226
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.377083
#
#                                           comb_x_vars  comb_error
# 0                                    [PlateLocHeight]    0.376674
# 1                      [PlateLocHeight, VertRelAngle]    0.372859
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]    0.365386
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.359540
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.354040
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.351365
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.349742
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.349522
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345567
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345425
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345448
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345235
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345231
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345168
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345136
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.344700
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.344626
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.344431
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.344459

# %%
pitches_features = feature.sort_values(by='validation error').iloc[0,:]['subset']
pitches_features
# Out:
# array(['VertApprAngle', 'VertRelAngle', 'PlateLocHeight', 'PlateLocSide',
#        'Strikes', 'HorzRelAngle', 'RelSpeed', 'InducedVertBreak',
#        'SpinRate', 'SpinAxis', 'HorzApprAngle', 'HorzBreak', 'Balls',
#        'Outs', 'BatterSide', 'Extension', 'PitcherThrows', 'RelHeight'],
#       dtype=object)

# %%
len(pitches_features)
# Out:
# 18

# %%
# Hyperparameter optimization using Optuna framework
# This systematically searches for the best XGBoost parameters to minimize log loss
def optimze_params(X_train, y_train):
    """
    Optimize XGBoost hyperparameters using Optuna's Tree-structured Parzen Estimator
    
    Parameters optimized:
    - max_depth: Tree depth (complexity control)
    - learning_rate: Step size shrinkage (overfitting control)  
    - n_estimators: Number of boosting rounds
    - colsample_bytree: Feature sampling ratio
    - min_child_weight: Minimum sum of instance weight in child
    
    Args:
        X_train: Training features
        y_train: Training target
        
    Returns:
        Dictionary of optimal hyperparameters
    """
    def objective(trial):
        # Define hyperparameter search space
        param = {
            'objective': 'binary:logistic',
            'eval_metric': 'logloss',
            'max_depth': trial.suggest_int('max_depth', 2, 10),
            'learning_rate': trial.suggest_float('learning_rate', 1e-3, 1e1, log=True),
            'n_estimators': trial.suggest_int('n_estimators', 50, 500),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
            'seed': 69  # Fixed seed for reproducibility
        }
        
        # Train model with current hyperparameters
        model = XGBClassifier(**param, enable_categorical=True)
        model.fit(X_train, y_train)

        # Evaluate on training set (Note: could use validation set for better generalization)
        y_pred = model.predict_proba(X_train)[:, 1]
        return log_loss(y_train, y_pred)
    
    # Create optimization study and run trials
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=50)
    return study.best_params

# %%
new_X_train = X_train[new_X_train_columns]
new_X_test = X_test[new_X_train_columns]

# %%
best_params = optimze_params(new_X_train,y_train)
# Out:
# [I 2025-08-08 19:00:14,505] A new study created in memory with name: no-name-3828d85e-4f9c-4587-9607-edfe74142e27
# [I 2025-08-08 19:00:25,301] Trial 0 finished with value: 0.29218876606715316 and parameters: {'max_depth': 3, 'learning_rate': 0.6125803017381213, 'n_estimators': 93, 'colsample_bytree': 0.5809463420007095, 'min_child_weight': 4}. Best is trial 0 with value: 0.29218876606715316.
# [I 2025-08-08 19:01:32,036] Trial 1 finished with value: 0.3109351332298076 and parameters: {'max_depth': 9, 'learning_rate': 0.0032411865404036043, 'n_estimators': 333, 'colsample_bytree': 0.8181195402299928, 'min_child_weight': 9}. Best is trial 0 with value: 0.29218876606715316.
# [I 2025-08-08 19:02:05,108] Trial 2 finished with value: 0.24257044931689428 and parameters: {'max_depth': 9, 'learning_rate': 0.5158132202078984, 'n_estimators': 201, 'colsample_bytree': 0.5325941505657124, 'min_child_weight': 3}. Best is trial 2 with value: 0.24257044931689428.
# [I 2025-08-08 19:02:58,535] Trial 3 finished with value: 0.3394420457704001 and parameters: {'max_depth': 9, 'learning_rate': 0.0011147648817589552, 'n_estimators': 180, 'colsample_bytree': 0.936919705095006, 'min_child_weight': 9}. Best is trial 2 with value: 0.24257044931689428.
# [I 2025-08-08 19:03:42,829] Trial 4 finished with value: 0.2878152340280106 and parameters: {'max_depth': 5, 'learning_rate': 0.06756610074957933, 'n_estimators': 380, 'colsample_bytree': 0.991853331968225, 'min_child_weight': 4}. Best is trial 2 with value: 0.24257044931689428.
# [I 2025-08-08 19:04:10,283] Trial 5 finished with value: 0.3220114135491527 and parameters: {'max_depth': 2, 'learning_rate': 0.0050804020930680415, 'n_estimators': 426, 'colsample_bytree': 0.6538169264753948, 'min_child_weight': 4}. Best is trial 2 with value: 0.24257044931689428.
# [I 2025-08-08 19:04:59,376] Trial 6 finished with value: 0.23691612001269294 and parameters: {'max_depth': 10, 'learning_rate': 0.19532842809654383, 'n_estimators': 342, 'colsample_bytree': 0.90601621290627, 'min_child_weight': 5}. Best is trial 6 with value: 0.23691612001269294.
# [I 2025-08-08 19:05:07,067] Trial 7 finished with value: 0.3138178577849305 and parameters: {'max_depth': 4, 'learning_rate': 1.7124783652790356, 'n_estimators': 74, 'colsample_bytree': 0.7917447702458469, 'min_child_weight': 6}. Best is trial 6 with value: 0.23691612001269294.
# [I 2025-08-08 19:05:14,802] Trial 8 finished with value: 4.284856140551683 and parameters: {'max_depth': 9, 'learning_rate': 8.515963766882944, 'n_estimators': 56, 'colsample_bytree': 0.8863777254150276, 'min_child_weight': 10}. Best is trial 6 with value: 0.23691612001269294.
# [I 2025-08-08 19:05:32,630] Trial 9 finished with value: 0.34668041639577996 and parameters: {'max_depth': 2, 'learning_rate': 0.0013652016472536469, 'n_estimators': 103, 'colsample_bytree': 0.9208591563490935, 'min_child_weight': 1}. Best is trial 6 with value: 0.23691612001269294.
# [I 2025-08-08 19:06:40,029] Trial 10 finished with value: 0.28473528073243703 and parameters: {'max_depth': 7, 'learning_rate': 0.034667205992859315, 'n_estimators': 471, 'colsample_bytree': 0.708006967995121, 'min_child_weight': 7}. Best is trial 6 with value: 0.23691612001269294.
# [I 2025-08-08 19:07:20,089] Trial 11 finished with value: 0.21857833549042302 and parameters: {'max_depth': 10, 'learning_rate': 0.3590118736207309, 'n_estimators': 255, 'colsample_bytree': 0.5045413513341619, 'min_child_weight': 1}. Best is trial 11 with value: 0.21857833549042302.
# [I 2025-08-08 19:07:55,450] Trial 12 finished with value: 0.2721056212138122 and parameters: {'max_depth': 7, 'learning_rate': 0.23617574937536587, 'n_estimators': 273, 'colsample_bytree': 0.5008599830003937, 'min_child_weight': 1}. Best is trial 11 with value: 0.21857833549042302.
# [I 2025-08-08 19:08:53,983] Trial 13 finished with value: 0.2828924467738832 and parameters: {'max_depth': 10, 'learning_rate': 0.020601045440393335, 'n_estimators': 295, 'colsample_bytree': 0.6317213689480188, 'min_child_weight': 2}. Best is trial 11 with value: 0.21857833549042302.
# [I 2025-08-08 19:09:06,280] Trial 14 finished with value: 1.984446620111658 and parameters: {'max_depth': 7, 'learning_rate': 2.155531576888782, 'n_estimators': 229, 'colsample_bytree': 0.7274865194399255, 'min_child_weight': 7}. Best is trial 11 with value: 0.21857833549042302.
# [I 2025-08-08 19:10:27,128] Trial 15 finished with value: 0.2368597573310599 and parameters: {'max_depth': 10, 'learning_rate': 0.1811763746851699, 'n_estimators': 376, 'colsample_bytree': 0.8355237486579477, 'min_child_weight': 5}. Best is trial 11 with value: 0.21857833549042302.
# [I 2025-08-08 19:11:31,470] Trial 16 finished with value: 0.2890446833993504 and parameters: {'max_depth': 8, 'learning_rate': 0.014825836184763058, 'n_estimators': 404, 'colsample_bytree': 0.8451030051954109, 'min_child_weight': 2}. Best is trial 11 with value: 0.21857833549042302.
# [I 2025-08-08 19:12:02,447] Trial 17 finished with value: 0.28372704102816243 and parameters: {'max_depth': 6, 'learning_rate': 0.11451323296771877, 'n_estimators': 265, 'colsample_bytree': 0.767127776397678, 'min_child_weight': 6}. Best is trial 11 with value: 0.21857833549042302.
# [I 2025-08-08 19:13:16,082] Trial 18 finished with value: 0.1182098865425981 and parameters: {'max_depth': 10, 'learning_rate': 1.040384824071943, 'n_estimators': 489, 'colsample_bytree': 0.6599724100951363, 'min_child_weight': 8}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:13:35,476] Trial 19 finished with value: 1.7360215393071001 and parameters: {'max_depth': 8, 'learning_rate': 6.49974478401383, 'n_estimators': 490, 'colsample_bytree': 0.5872259825693287, 'min_child_weight': 8}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:14:00,707] Trial 20 finished with value: 0.28375129238318875 and parameters: {'max_depth': 8, 'learning_rate': 1.8236310119466794, 'n_estimators': 154, 'colsample_bytree': 0.63883505218204, 'min_child_weight': 8}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:15:01,677] Trial 21 finished with value: 0.14667040404987003 and parameters: {'max_depth': 10, 'learning_rate': 0.7151358346322771, 'n_estimators': 437, 'colsample_bytree': 0.7076376919396036, 'min_child_weight': 5}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:16:02,991] Trial 22 finished with value: 0.1587954675487717 and parameters: {'max_depth': 10, 'learning_rate': 0.6593187989023502, 'n_estimators': 449, 'colsample_bytree': 0.6815998272630511, 'min_child_weight': 7}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:17:11,920] Trial 23 finished with value: 0.12990868113211446 and parameters: {'max_depth': 10, 'learning_rate': 0.8998437015432517, 'n_estimators': 455, 'colsample_bytree': 0.6934176041168348, 'min_child_weight': 7}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:17:33,963] Trial 24 finished with value: 4.69347210692956 and parameters: {'max_depth': 9, 'learning_rate': 3.587141698852874, 'n_estimators': 492, 'colsample_bytree': 0.7419230989641536, 'min_child_weight': 8}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:18:28,211] Trial 25 finished with value: 0.20587035965771472 and parameters: {'max_depth': 8, 'learning_rate': 1.1952132267082547, 'n_estimators': 442, 'colsample_bytree': 0.6836277628873924, 'min_child_weight': 6}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:19:10,268] Trial 26 finished with value: 0.2624141065702504 and parameters: {'max_depth': 6, 'learning_rate': 0.986192176348298, 'n_estimators': 405, 'colsample_bytree': 0.6063041309073115, 'min_child_weight': 9}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:19:31,143] Trial 27 finished with value: 1.753207249483051 and parameters: {'max_depth': 10, 'learning_rate': 3.8846611371185684, 'n_estimators': 452, 'colsample_bytree': 0.6804152170820823, 'min_child_weight': 10}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:20:43,767] Trial 28 finished with value: 0.26588539901765224 and parameters: {'max_depth': 9, 'learning_rate': 0.07240240511111551, 'n_estimators': 499, 'colsample_bytree': 0.7690158744645085, 'min_child_weight': 7}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:21:12,579] Trial 29 finished with value: 0.28324061865828404 and parameters: {'max_depth': 4, 'learning_rate': 0.6654357635870106, 'n_estimators': 333, 'colsample_bytree': 0.5535466240960486, 'min_child_weight': 5}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:21:33,647] Trial 30 finished with value: 5.579047209786464 and parameters: {'max_depth': 8, 'learning_rate': 3.5029741814522097, 'n_estimators': 418, 'colsample_bytree': 0.7126540871620402, 'min_child_weight': 8}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:22:41,632] Trial 31 finished with value: 0.16046341836032943 and parameters: {'max_depth': 10, 'learning_rate': 0.619347960793339, 'n_estimators': 462, 'colsample_bytree': 0.6758398543701919, 'min_child_weight': 7}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:23:37,598] Trial 32 finished with value: 0.21975583514632524 and parameters: {'max_depth': 10, 'learning_rate': 0.3027673054300434, 'n_estimators': 377, 'colsample_bytree': 0.607167198585484, 'min_child_weight': 6}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:24:38,089] Trial 33 finished with value: 0.18620592931236393 and parameters: {'max_depth': 9, 'learning_rate': 0.8527161897649798, 'n_estimators': 443, 'colsample_bytree': 0.7016320443489408, 'min_child_weight': 9}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:25:47,344] Trial 34 finished with value: 0.18028671826562032 and parameters: {'max_depth': 10, 'learning_rate': 0.4794427883968236, 'n_estimators': 470, 'colsample_bytree': 0.6562048802467957, 'min_child_weight': 7}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:26:43,585] Trial 35 finished with value: 0.1666653600860273 and parameters: {'max_depth': 9, 'learning_rate': 1.2510209508203167, 'n_estimators': 362, 'colsample_bytree': 0.7944156406452969, 'min_child_weight': 4}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:27:27,530] Trial 36 finished with value: 0.23310480881164025 and parameters: {'max_depth': 9, 'learning_rate': 0.4648381385302622, 'n_estimators': 305, 'colsample_bytree': 0.7494834741279698, 'min_child_weight': 8}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:28:31,297] Trial 37 finished with value: 0.24661443766500105 and parameters: {'max_depth': 10, 'learning_rate': 0.1361404377566897, 'n_estimators': 400, 'colsample_bytree': 0.571014436616227, 'min_child_weight': 5}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:28:52,951] Trial 38 finished with value: 1.985299030903142 and parameters: {'max_depth': 9, 'learning_rate': 2.3939017483168747, 'n_estimators': 429, 'colsample_bytree': 0.649561495833605, 'min_child_weight': 6}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:29:36,315] Trial 39 finished with value: 0.2730393510699053 and parameters: {'max_depth': 5, 'learning_rate': 1.3056319202503561, 'n_estimators': 471, 'colsample_bytree': 0.6234920385423286, 'min_child_weight': 9}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:30:29,255] Trial 40 finished with value: 0.21699602236157423 and parameters: {'max_depth': 10, 'learning_rate': 0.300222614294593, 'n_estimators': 342, 'colsample_bytree': 0.6693733356381166, 'min_child_weight': 3}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:31:37,478] Trial 41 finished with value: 0.15010169673030685 and parameters: {'max_depth': 10, 'learning_rate': 0.7005859549169677, 'n_estimators': 460, 'colsample_bytree': 0.6868782177520653, 'min_child_weight': 7}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:32:36,999] Trial 42 finished with value: 0.18818154047257685 and parameters: {'max_depth': 9, 'learning_rate': 0.766020044179421, 'n_estimators': 434, 'colsample_bytree': 0.6964710103265211, 'min_child_weight': 7}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:32:58,566] Trial 43 finished with value: 7.269101993722037 and parameters: {'max_depth': 10, 'learning_rate': 5.916158310176824, 'n_estimators': 484, 'colsample_bytree': 0.7221427536037301, 'min_child_weight': 8}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:33:59,599] Trial 44 finished with value: 0.21180590891768103 and parameters: {'max_depth': 9, 'learning_rate': 0.41590343585348266, 'n_estimators': 457, 'colsample_bytree': 0.9996657584707977, 'min_child_weight': 6}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:34:20,937] Trial 45 finished with value: 1.6633606793763922 and parameters: {'max_depth': 10, 'learning_rate': 2.588429329062443, 'n_estimators': 396, 'colsample_bytree': 0.7754085559560542, 'min_child_weight': 7}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:35:23,529] Trial 46 finished with value: 0.2228061541798391 and parameters: {'max_depth': 10, 'learning_rate': 0.2267208774356741, 'n_estimators': 423, 'colsample_bytree': 0.7397664886053625, 'min_child_weight': 5}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:35:59,113] Trial 47 finished with value: 0.29594113085857743 and parameters: {'max_depth': 3, 'learning_rate': 0.047651476049390094, 'n_estimators': 474, 'colsample_bytree': 0.6608590048359965, 'min_child_weight': 4}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:37:06,475] Trial 48 finished with value: 0.2494518778866416 and parameters: {'max_depth': 9, 'learning_rate': 0.1541483893952588, 'n_estimators': 500, 'colsample_bytree': 0.6228025823367367, 'min_child_weight': 7}. Best is trial 18 with value: 0.1182098865425981.
# [I 2025-08-08 19:37:57,457] Trial 49 finished with value: 0.22853573143658196 and parameters: {'max_depth': 8, 'learning_rate': 1.5275217454420917, 'n_estimators': 358, 'colsample_bytree': 0.7206829729821885, 'min_child_weight': 9}. Best is trial 18 with value: 0.1182098865425981.

# %%
# Final model training and prediction function
# Uses optimized hyperparameters to train the final model and generate predictions
def create_model(X_train, y_train, X_test, param):
    """
    Train final XGBoost model with optimized parameters and generate predictions
    
    Args:
        X_train: Training features
        y_train: Training target
        X_test: Test features
        param: Optimized hyperparameters from Optuna
        
    Returns:
        y_pred: Predicted probabilities for test set (xWhiff values)
    """
    # Initialize model with optimal parameters
    model = XGBClassifier(**param, enable_categorical=True)
    
    # Train on full training set
    model.fit(X_train, y_train)

    # Generate probability predictions (xWhiff scores)
    y_pred = model.predict_proba(X_test)[:, 1]  # Probability of whiff (class 1)
    return y_pred

# %%
# Generate xWhiff predictions for 2024 test data
# Apply the optimized model to create expected whiff probability for each pitch
xwhiff = create_model(new_X_train, y_train, new_X_test, best_params)
test['xwhiff'] = xwhiff

print(f"xWhiff predictions generated for {len(test)} pitches")
print(f"Mean xWhiff: {test['xwhiff'].mean():.3f}")
print(f"xWhiff range: {test['xwhiff'].min():.3f} to {test['xwhiff'].max():.3f}")
# Out:
# xWhiff predictions generated for 1299546 pitches
# Mean xWhiff: 0.095
# xWhiff range: 0.000 to 1.000

# %%
# Display the final dataset with xWhiff predictions
# This shows the original pitch data enhanced with expected whiff probabilities
test
# Out:
#         PitcherThrows BatterSide  Outs  Balls  Strikes TaggedPitchType  \
# 0               Right      Right     0      0        0          Slider
# 1               Right      Right     0      1        0        Fastball
# 2               Right      Right     0      1        1        Fastball
# 3               Right      Right     0      1        2          Slider
# 4               Right      Right     0      1        2          Slider
# ...               ...        ...   ...    ...      ...             ...
# 1299541         Right       Left     1      0        2        Fastball
# 1299542         Right      Right     2      0        0        Fastball
# 1299543         Right      Right     2      0        1        Fastball
# 1299544         Right      Right     2      0        2        Fastball
# 1299545         Right      Right     2      1        2          Slider
#
#                     PitchCall  RelSpeed  VertRelAngle  HorzRelAngle  ...  \
# 0                  BallCalled  86.34831     -5.087035     -0.556059  ...
# 1                StrikeCalled  94.49974     -3.133086     -0.492520  ...
# 2        FoulBallNotFieldable  94.81021     -3.910073     -1.135525  ...
# 3        FoulBallNotFieldable  86.30865     -1.385858     -0.791508  ...
# 4                  BallCalled  87.45870     -4.605749     -1.323250  ...
# ...                       ...       ...           ...           ...  ...
# 1299541        StrikeSwinging  92.18631      0.167760     -2.363777  ...
# 1299542          StrikeCalled  92.64280     -0.263162     -3.510955  ...
# 1299543        StrikeSwinging  93.60782     -0.195835     -2.925634  ...
# 1299544            BallCalled  92.70635      1.555863     -3.913135  ...
# 1299545        StrikeSwinging  78.95801      1.401154     -0.864378  ...
#
#          InducedVertBreak  HorzBreak  PlateLocHeight  PlateLocSide  \
# 0                -1.26150   -6.71201        -1.24052      -0.79734
# 1                20.20828    3.49654         3.00046       0.29788
# 2                22.06875   -0.43740         2.48669      -0.87744
# 3                 2.34610   -6.38485         2.69703      -1.15108
# 4                 0.27646   -4.37162        -0.43496      -1.44974
# ...                   ...        ...             ...           ...
# 1299541          12.64422   18.25938         3.18957       0.77831
# 1299542          15.40280   13.05642         3.09837      -0.84427
# 1299543          17.26068   10.25316         3.60768      -0.76626
# 1299544          16.00694   10.33784         4.86704      -1.41462
# 1299545         -12.73579  -17.86462         1.23877      -0.92484
#
#          VertApprAngle  HorzApprAngle     PitcherId  whiff  count  \
# 0           -12.231122      -1.751516  1.000234e+09      0    0-0
# 1            -5.365324       0.134391  1.000234e+09      0    1-0
# 2            -5.815582      -1.213668  1.000234e+09      0    1-1
# 3            -7.862841      -1.929632  1.000234e+09      0    1-2
# 4           -11.264591      -2.102031  1.000234e+09      0    1-2
# ...                ...            ...           ...    ...    ...
# 1299541      -3.753137       0.867156  6.945510e+05      1    0-2
# 1299542      -3.653929      -1.209960  6.945510e+05      0    0-0
# 1299543      -3.090463      -1.109277  6.945510e+05      1    0-1
# 1299544      -1.669483      -2.081033  6.945510e+05      0    0-2
# 1299545      -9.377512      -4.014747  6.945510e+05      1    1-2
#
#                xwhiff
# 0        2.374117e-05
# 1        1.572481e-01
# 2        1.232651e-01
# 3        2.282267e-04
# 4        1.313846e-04
# ...               ...
# 1299541  6.409772e-02
# 1299542  1.198737e-03
# 1299543  6.833382e-02
# 1299544  1.192337e-11
# 1299545  1.150274e-01
#
# [1299546 rows x 25 columns]

# %%
# Export the enhanced dataset for use in inference and analysis
# This file contains all original features plus the new xWhiff metric for further study
test.to_csv('./whiff_csvs/2024_xwhiff_college.csv', index=False)

print("Dataset exported successfully!")
print("Ready for inference analysis and pitch tunneling studies.")
# Out:
# Dataset exported successfully!
# Ready for inference analysis and pitch tunneling studies.
