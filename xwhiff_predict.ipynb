# %%
# XWhiff Model Training and Prediction
# This notebook develops and optimizes an XGBoost model to predict swing-and-miss probability
# 
# Import necessary libraries for model development and optimization
import pandas as pd                      # Data manipulation and analysis
import numpy as np                       # Numerical operations
import xgboost as xgb                    # Gradient boosting framework
from xgboost import XGBClassifier        # XGBoost classifier for binary classification
from sklearn.linear_model import LogisticRegression  # Alternative linear model
import matplotlib.pyplot as plt          # Basic plotting functionality
import seaborn as sns                    # Statistical data visualization
import sklearn                           # Machine learning library
from sklearn.model_selection import KFold  # Cross-validation functionality
from sklearn.metrics import log_loss     # Evaluation metric for binary classification
import optuna                            # Hyperparameter optimization framework

# %%
# Load cleaned pitch tracking data from multiple seasons
# This provides a comprehensive dataset spanning multiple years for robust model training
clean_2024 = pd.read_csv('./whiff_csvs/2024_whiff_clean.csv', low_memory=False)  # Test data
clean_2023 = pd.read_csv('./whiff_csvs/2023_whiff_clean.csv', low_memory=False)  # Training data
clean_2022 = pd.read_csv('./whiff_csvs/2022_whiff_clean.csv', low_memory=False)  # Training data

# %%
# Note: Remove any commented code blocks that are no longer needed
# This keeps the notebook clean and focused on the current methodology

# %%
clean_2022.head()
# Out:
#   PitcherThrows BatterSide  Outs  Balls  Strikes TaggedPitchType  \
# 0         Right      Right     0      0        0        Fastball
# 1         Right      Right     0      1        0        Fastball
# 2         Right      Right     0      2        0        Fastball
# 3         Right      Right     0      2        1        Fastball
# 4         Right      Right     0      2        2        Fastball
#
#       PitchCall  RelSpeed  VertRelAngle  HorzRelAngle  ...  Extension  \
# 0    BallCalled  91.80411     -3.816351     -3.522621  ...    5.74749
# 1    BallCalled  92.38028     -3.537349     -3.658209  ...    5.55677
# 2  StrikeCalled  92.75261     -3.209314     -2.573778  ...    5.49731
# 3      FoulBall  92.35726     -2.446575     -2.958796  ...    5.58153
# 4        InPlay  94.60763     -3.377392     -2.749154  ...    5.70240
#
#    InducedVertBreak  HorzBreak  PlateLocHeight  PlateLocSide  VertApprAngle  \
# 0          18.08218   12.78119         1.16387      -0.26392      -6.801089
# 1          16.22639   14.28202         1.28412      -0.42104      -6.825532
# 2          17.84517   12.29304         1.84823       0.54753      -6.174757
# 3          19.67907   10.39461         2.68124       0.10833      -5.096501
# 4          17.33721   14.15202         1.78420       0.58484      -6.062640
#
#    HorzApprAngle     PitcherId  whiff  count
# 0      -1.239948  1.000074e+09      0    0-0
# 1      -1.116474  1.000074e+09      0    1-0
# 2      -0.385627  1.000074e+09      0    2-0
# 3      -1.107350  1.000074e+09      0    2-1
# 4      -0.220896  1.000074e+09      0    2-2
#
# [5 rows x 24 columns]

# %%
clean_2023.head()
# Out:
#   PitcherThrows BatterSide  Outs  Balls  Strikes TaggedPitchType  \
# 0         Right       Left     0      0        0        Fastball
# 1         Right       Left     0      0        0        ChangeUp
# 2         Right       Left     0      0        1        Fastball
# 3         Right       Left     0      1        1       Curveball
# 4         Right       Left     0      2        1        ChangeUp
#
#       PitchCall  RelSpeed  VertRelAngle  HorzRelAngle  ...  RelSide  \
# 0        InPlay  88.43126     -3.720299     -0.585480  ...  0.59849
# 1  StrikeCalled  80.24299     -0.945260     -1.525434  ...  0.71170
# 2    BallCalled  87.42133     -3.303045     -0.520038  ...  0.69940
# 3    BallCalled  72.85011     -1.028297      0.347481  ...  0.30630
# 4        InPlay  82.40725     -2.265863     -1.333121  ...  0.72582
#
#    Extension  InducedVertBreak  HorzBreak  PlateLocHeight  PlateLocSide  \
# 0    5.88136          23.19308   10.90638         1.91630       0.96361
# 1    6.53191          11.33949   11.80068         2.80934       0.29542
# 2    5.79229          21.80682   10.33725         2.09101       1.07706
# 3    5.85791         -10.56816  -17.28883         0.22062      -0.81158
# 4    6.82618          12.77918   13.40245         1.81788       0.62639
#
#    VertApprAngle  HorzApprAngle  whiff  count
# 0      -6.304004       1.371603      0    0-0
# 1      -6.900707       0.619730      0    0-0
# 2      -6.285148       1.332128      0    0-1
# 3     -12.684304      -2.772901      0    1-1
# 4      -7.448031       1.117945      0    2-1
#
# [5 rows x 23 columns]

# %%
clean_2024.head()
# Out:
#   PitcherThrows BatterSide  Outs  Balls  Strikes TaggedPitchType  \
# 0         Right      Right     0      0        0          Slider
# 1         Right      Right     0      1        0        Fastball
# 2         Right      Right     0      1        1        Fastball
# 3         Right      Right     0      1        2          Slider
# 4         Right      Right     0      1        2          Slider
#
#               PitchCall  RelSpeed  VertRelAngle  HorzRelAngle  ...  Extension  \
# 0            BallCalled  86.34831     -5.087035     -0.556059  ...    5.20061
# 1          StrikeCalled  94.49974     -3.133086     -0.492520  ...    5.83655
# 2  FoulBallNotFieldable  94.81021     -3.910073     -1.135525  ...    5.67326
# 3  FoulBallNotFieldable  86.30865     -1.385858     -0.791508  ...    5.43599
# 4            BallCalled  87.45870     -4.605749     -1.323250  ...    5.28786
#
#    InducedVertBreak  HorzBreak  PlateLocHeight  PlateLocSide  VertApprAngle  \
# 0          -1.26150   -6.71201        -1.24052      -0.79734     -12.231122
# 1          20.20828    3.49654         3.00046       0.29788      -5.365324
# 2          22.06875   -0.43740         2.48669      -0.87744      -5.815582
# 3           2.34610   -6.38485         2.69703      -1.15108      -7.862841
# 4           0.27646   -4.37162        -0.43496      -1.44974     -11.264591
#
#    HorzApprAngle     PitcherId  whiff  count
# 0      -1.751516  1.000234e+09      0    0-0
# 1       0.134391  1.000234e+09      0    1-0
# 2      -1.213668  1.000234e+09      0    1-1
# 3      -1.929632  1.000234e+09      0    1-2
# 4      -2.102031  1.000234e+09      0    1-2
#
# [5 rows x 24 columns]

# %%
# Create train/test split using temporal separation
# 2024 data as test set provides realistic out-of-time validation
# 2022-2023 combined data provides sufficient training samples
test = clean_2024.copy()
train = pd.concat([clean_2023.copy(), clean_2022.copy()])

# %% [markdown]
# # Model Development Strategy
#
# ## Feature Selection Objectives
# The primary goals of this analysis are:
# 1. **Feature Selection**: Identify which pitch characteristics are most predictive of swing-and-miss outcomes
# 2. **Model Architecture**: Determine if pitch-type-specific models outperform a unified model
# 3. **Temporal Validation**: Use 2022-2023 data for training and 2024 for testing to ensure robust performance
#
# ## Pitch Type Segmentation Considerations
# While grouping pitches by type (fastball, breaking ball, offspeed) seems logical due to similar movement profiles, several challenges exist:
#
# ### Data Quality Challenges
# - **Subjective Tagging**: Pitch classification relies on human judgment, leading to inconsistencies
# - **Operator Variability**: Different taggers may classify similar pitches differently
# - **Edge Cases**: Borderline pitches (e.g., hard slider vs. cutter) are particularly prone to misclassification
#
# ### Cleaning Limitations
# Automated pitch type correction is difficult because:
# - Pitch types exist on a spectrum rather than discrete categories
# - Movement parameters can overlap significantly between pitch types
# - Contextual factors (game situation, pitcher intent) influence classification
#
# ## Methodology
# - **Training Data**: Combined 2022-2023 seasons for maximum sample size
# - **Test Data**: 2024 season for out-of-time validation
# - **Evaluation**: Compare unified model vs. pitch-type-specific models using cross-validation

# %%
# Examine data types in the combined training dataset
# This helps identify any type inconsistencies between seasons that need addressing
train.dtypes
# Out:
# PitcherThrows        object
# BatterSide           object
# Outs                  int64
# Balls                 int64
# Strikes               int64
# TaggedPitchType      object
# PitchCall            object
# RelSpeed            float64
# VertRelAngle        float64
# HorzRelAngle        float64
# SpinRate            float64
# SpinAxis            float64
# RelHeight           float64
# RelSide             float64
# Extension           float64
# InducedVertBreak    float64
# HorzBreak           float64
# PlateLocHeight      float64
# PlateLocSide        float64
# VertApprAngle       float64
# HorzApprAngle       float64
# whiff                 int64
# count                object
# PitcherId           float64
# dtype: object

# %%
# Convert categorical variables to proper data types for XGBoost
# XGBoost with enable_categorical=True can handle categorical features more efficiently
# This ensures handedness variables are treated as discrete categories, not ordinal
train['PitcherThrows'] = train['PitcherThrows'].astype('category')
train['BatterSide'] = train['BatterSide'].astype('category')
test['PitcherThrows'] = test['PitcherThrows'].astype('category')
test['BatterSide'] = test['BatterSide'].astype('category')

# %%
# Function to extract features and target variable from dataset
# This standardizes the feature selection process across different data splits
def split(df):
    """
    Extract features and target variable for model training/testing
    
    Features include:
    - Game situation: PitcherThrows, BatterSide, Outs, Balls, Strikes
    - Pitch characteristics: RelSpeed, VertRelAngle, HorzRelAngle, SpinRate, SpinAxis
    - Release point: RelHeight, RelSide, Extension
    - Movement: InducedVertBreak, HorzBreak
    - Location: PlateLocHeight, PlateLocSide, VertApprAngle, HorzApprAngle
    """
    X = df[['PitcherThrows', 'BatterSide', 'Outs', 'Balls', 'Strikes',
            'RelSpeed', 'VertRelAngle', 'HorzRelAngle', 'SpinRate', 'SpinAxis',
            'RelHeight', 'RelSide', 'Extension', 'InducedVertBreak', 'HorzBreak',
            'PlateLocHeight', 'PlateLocSide', 'VertApprAngle', 'HorzApprAngle']]
    y = df['whiff']
    return X, y

# Apply feature extraction to both training and test sets
X_train, y_train = split(train)
X_test, y_test = split(test)

# %%
# Cross-validation function to evaluate model performance
# Uses 5-fold CV with log loss metric for binary classification evaluation
def CV(X_train, Y_train):
    """
    Perform 5-fold cross-validation to estimate model performance
    
    Args:
        X_train: Feature matrix
        Y_train: Target variable (binary: whiff/no-whiff)
    
    Returns:
        Mean log loss across all folds (lower is better)
    """
    model = XGBClassifier(enable_categorical=True)  # Enable categorical feature handling
    kf = KFold(n_splits=5, shuffle=True, random_state=42)  # 5-fold CV with shuffling
    validation_errors = np.empty(0)

    for train_idx, valid_idx in kf.split(X_train):
        # Split data for this fold
        split_X_train, split_X_valid = X_train.iloc[train_idx, :], X_train.iloc[valid_idx, :]
        split_Y_train, split_Y_valid = Y_train.iloc[train_idx], Y_train.iloc[valid_idx] 
        
        # Train model on training fold
        model.fit(split_X_train, split_Y_train)
        
        # Predict probabilities on validation fold
        Y_pred = model.predict_proba(split_X_valid)[:, 1]  # Probability of whiff (class 1)
        
        # Calculate log loss for this fold
        validation_errors = np.append(validation_errors, log_loss(split_Y_valid, Y_pred))
    
    return np.mean(validation_errors)

# %%
# Calculate baseline cross-validation error using all features
# This establishes our benchmark performance before feature selection
CV_errors = pd.DataFrame({'cv_error': np.array(CV(X_train, y_train))}, index=[0])
CV_errors
# Out:
#    cv_error
# 0  0.289485

# %%
# Initialize dataframe to store individual feature performance
# This will help us understand the predictive power of each feature independently
feature_errors = pd.DataFrame({"feature_name": X_train.columns})
feature_errors
# Out:
#         feature_name
# 0      PitcherThrows
# 1         BatterSide
# 2               Outs
# 3              Balls
# 4            Strikes
# 5           RelSpeed
# 6       VertRelAngle
# 7       HorzRelAngle
# 8           SpinRate
# 9           SpinAxis
# 10         RelHeight
# 11           RelSide
# 12         Extension
# 13  InducedVertBreak
# 14         HorzBreak
# 15    PlateLocHeight
# 16      PlateLocSide
# 17     VertApprAngle
# 18     HorzApprAngle

# %%
# Evaluate individual feature performance using single-feature models
# This identifies which features have the strongest independent predictive power
def feature_error(X_train, Y_train):
    """
    Test each feature individually to assess its predictive power
    
    Args:
        X_train: Full feature matrix
        Y_train: Target variable
    
    Returns:
        DataFrame with feature names and their individual CV errors
    """
    feature_errors = pd.DataFrame({"feature_name": X_train.columns})
    model = XGBClassifier(enable_categorical=True)
    feature_error = np.empty(0)

    # Test each feature individually
    for x_var in X_train.columns:
        print(f"Testing feature: {x_var}")
        
        # Create single-feature dataset
        X = X_train[[x_var]]
       
        kf = KFold(n_splits=5, shuffle=True, random_state=42)
        validation_errors = np.empty(0)

        # Cross-validate single-feature model
        for train_idx, valid_idx in kf.split(X_train):
            split_X_train, split_X_valid = X.iloc[train_idx, :], X.iloc[valid_idx, :]
            split_Y_train, split_Y_valid = Y_train.iloc[train_idx], Y_train.iloc[valid_idx] 
            
            model.fit(split_X_train, split_Y_train)
            Y_pred = model.predict_proba(split_X_valid)[:, 1]
            validation_errors = np.append(validation_errors, log_loss(split_Y_valid, Y_pred))
        
        # Store mean error for this feature
        feature_error = np.append(feature_error, np.mean(validation_errors))
    
    feature_errors['error'] = feature_error
    return feature_errors

# Execute feature importance analysis
errors = feature_error(X_train, y_train)
errors
# Out:
#         feature_name     error
# 0      PitcherThrows  0.334509
# 1         BatterSide  0.334460
# 2               Outs  0.334349
# 3              Balls  0.333855
# 4            Strikes  0.330373
# 5           RelSpeed  0.331889
# 6       VertRelAngle  0.328804
# 7       HorzRelAngle  0.331164
# 8           SpinRate  0.332835
# 9           SpinAxis  0.333033
# 10         RelHeight  0.334552
# 11           RelSide  0.334576
# 12         Extension  0.334514
# 13  InducedVertBreak  0.332069
# 14         HorzBreak  0.333583
# 15    PlateLocHeight  0.329134
# 16      PlateLocSide  0.329347
# 17     VertApprAngle  0.327775
# 18     HorzApprAngle  0.333270

# %%
feature_errors = errors.copy()

# %%
# Rank features by their individual predictive power (lowest error = best feature)
# This creates an ordered list from most to least important features
feature_importance = feature_errors.sort_values(by="error")["feature_name"]
feature_importance
# Out:
# 17       VertApprAngle
# 6         VertRelAngle
# 15      PlateLocHeight
# 16        PlateLocSide
# 4              Strikes
# 7         HorzRelAngle
# 5             RelSpeed
# 13    InducedVertBreak
# 8             SpinRate
# 9             SpinAxis
# 18       HorzApprAngle
# 14           HorzBreak
# 3                Balls
# 2                 Outs
# 1           BatterSide
# 0        PitcherThrows
# 12           Extension
# 10           RelHeight
# 11             RelSide
# Name: feature_name, dtype: object

# %%
# Forward feature selection: incrementally add features in order of importance
# This finds the optimal number of features by testing cumulative feature sets
def best_features(X_train, Y_train, feature_importance):
    """
    Perform forward feature selection using ranked feature importance
    
    Starting with the best individual feature, iteratively add the next best feature
    and evaluate performance until we find the optimal feature subset
    
    Args:
        X_train: Training features
        Y_train: Training target
        feature_importance: Features ranked by individual performance
    
    Returns:
        predictors: List of feature subsets tested
        feature_error: CV error for each feature subset
    """
    model = XGBClassifier(enable_categorical=True)
    feature_error = np.empty(0)
    predictors = []

    # Test each cumulative feature subset
    for i in np.arange(0, len(feature_importance)):
        print(f"Testing {i+1} features...")
        
        # Select top i+1 features
        X = X_train[np.array(feature_importance[0:i+1])]
        predictors.append(feature_importance[0:i+1].values)
    
        kf = KFold(n_splits=5, shuffle=True, random_state=42)
        validation_errors = np.empty(0)

        # Cross-validate this feature subset
        for train_idx, valid_idx in kf.split(X_train):
            split_X_train, split_X_valid = X.iloc[train_idx, :], X.iloc[valid_idx, :]
            split_Y_train, split_Y_valid = Y_train.iloc[train_idx], Y_train.iloc[valid_idx] 
            
            model.fit(split_X_train, split_Y_train)
            Y_pred = model.predict_proba(split_X_valid)[:, 1]
            validation_errors = np.append(validation_errors, log_loss(split_Y_valid, Y_pred))
        
        feature_error = np.append(feature_error, np.mean(validation_errors))
    
    return predictors, feature_error

# %%
# Execute forward feature selection to find optimal feature combination
# This process will test all cumulative feature subsets and find the best performing one
predictors, predict_error = best_features(X_train, y_train, feature_importance)
x_vars_errors = pd.DataFrame({"subset": predictors, "validation error": predict_error})

# %%
# Identify the optimal feature subset with lowest validation error
# This represents the best balance between model complexity and performance
feature = pd.DataFrame({"subset": predictors, "validation error": predict_error})
new_X_train_columns = feature.sort_values(by='validation error').iloc[0, 0]

# Note: Features like Extension, RelHeight, RelSide may be dropped if they don't improve performance
# This suggests these release point characteristics are less predictive than other features
new_X_train_columns
# Out:
# array(['VertApprAngle', 'VertRelAngle', 'PlateLocHeight', 'PlateLocSide',
#        'Strikes', 'HorzRelAngle', 'RelSpeed', 'InducedVertBreak',
#        'SpinRate', 'SpinAxis', 'HorzApprAngle', 'HorzBreak', 'Balls',
#        'Outs', 'BatterSide', 'PitcherThrows', 'Extension', 'RelHeight'],
#       dtype=object)

# %% [markdown]
# # Pitch Type-Specific Model Analysis
#
# Now we'll test whether separating pitches into distinct categories improves model performance. The hypothesis is that different pitch types (fastballs vs. breaking balls vs. offspeed) have fundamentally different characteristics that make swing-and-miss prediction, and specialized models might capture these nuances better than a unified approach.
#
# ## Approach
# We'll repeat the same feature selection process for three pitch categories:
# 1. **Fastballs**: Fastball, Sinker
# 2. **Breaking Balls**: Curveball, Cutter, Slider
# 3. **Offspeed**: ChangeUp
#
# This will allow us to compare:
# - **Unified Model**: Single model trained on all pitch types
# - **Specialized Models**: Separate models for each pitch category
# - **Feature Importance**: Whether different features matter for different pitch types

# %%
# Split datasets by pitch type categories for specialized model training
# Each category has different characteristics that may benefit from specialized modeling

# Fastball category: High velocity, minimal movement
FB_train = train[(train['TaggedPitchType'] == 'Fastball') | (train['TaggedPitchType'] == 'Sinker')]
FB_test = test[(test['TaggedPitchType'] == 'Fastball') | (test['TaggedPitchType'] == 'Sinker')]

# Breaking ball category: Significant movement, spin-dependent
BB_train = train[(train['TaggedPitchType'] == 'Curveball') | (train['TaggedPitchType'] == 'Cutter') | (train['TaggedPitchType'] == 'Slider')]
BB_test = test[(test['TaggedPitchType'] == 'Curveball') | (test['TaggedPitchType'] == 'Slider') | (test['TaggedPitchType'] == 'Cutter')]

# Offspeed category: Deception-based, velocity differential
OFF_train = train[(train['TaggedPitchType'] == 'ChangeUp')]
OFF_test = test[(test['TaggedPitchType'] == 'ChangeUp')]

# %% [markdown]
# # Cutter Classification Decision
#
# ## Initial Approach vs. Final Decision
# **Initial Classification**: Cutter grouped with fastballs due to velocity similarity (essentially opposite of sinker movement)
#
# **Final Classification**: Cutter moved to breaking ball category, though in the MLB cutters are often thought of and are thrown like Fastballs. In college baseball cutters are more commonly thrown as a breaking pitch similar to a Slider
#
# ## Reasoning for Change
# 1. **Movement Profile**: Despite velocity similarity to fastballs, cutters have movement characteristics closer to sliders
# 2. **Tagging Consistency**: Cutters are frequently mistagged as sliders during games due to visual similarity
# 3. **Performance Impact**: Moving cutters to the breaking ball category reduced log loss for both:
#    - Fastball models (more homogeneous group)
#    - Breaking ball models (better handles cutter-slider similarity)
#
# ## Key Insight
# This demonstrates how data quality issues (subjective pitch tagging) can inform modeling decisions. Sometimes grouping by observed characteristics (how pitches are actually classified) performs better than grouping by theoretical characteristics (how pitches should be classified).

# %%
FB_X_train, FB_y_train = split(FB_train)
FB_X_test, FB_y_test = split(FB_test)
BB_X_train, BB_y_train = split(BB_train)
BB_X_test, BB_X_test = split(BB_test)
OFF_X_train, OFF_y_train = split(OFF_train)
OFF_X_test, OFF_y_test = split(OFF_test)

# %%
#cv_errors feature_errors x_vars_errors
FB_CV = CV(FB_X_train,FB_y_train)
CV_errors['FB_CV_error'] = [FB_CV]
BB_CV = CV(BB_X_train,BB_y_train)
CV_errors['BB_CV_error'] = [BB_CV]
OFF_CV = CV(OFF_X_train,OFF_y_train)
CV_errors['OFF_CV_error'] = [OFF_CV]

# %%
CV_errors
# Out:
#    cv_error  FB_CV_error  BB_CV_error  OFF_CV_error
# 0  0.289485     0.246876     0.334365      0.379937

# %%
FB_feature_error = feature_error(FB_X_train,FB_y_train)
BB_feature_error = feature_error(BB_X_train,BB_y_train)
OFF_feature_error = feature_error(OFF_X_train,OFF_y_train)

# %%
FB_feature_error, BB_feature_error, OFF_feature_error
# Out:
# (        feature_name     error
#  0      PitcherThrows  0.281804
#  1         BatterSide  0.281798
#  2               Outs  0.281685
#  3              Balls  0.281267
#  4            Strikes  0.278391
#  5           RelSpeed  0.280480
#  6       VertRelAngle  0.279179
#  7       HorzRelAngle  0.279398
#  8           SpinRate  0.281102
#  9           SpinAxis  0.280957
#  10         RelHeight  0.281942
#  11           RelSide  0.281915
#  12         Extension  0.281899
#  13  InducedVertBreak  0.279886
#  14         HorzBreak  0.281556
#  15    PlateLocHeight  0.273658
#  16      PlateLocSide  0.276041
#  17     VertApprAngle  0.274555
#  18     HorzApprAngle  0.280907,
#          feature_name     error
#  0      PitcherThrows  0.385165
#  1         BatterSide  0.385086
#  2               Outs  0.385128
#  3              Balls  0.384107
#  4            Strikes  0.380265
#  5           RelSpeed  0.380502
#  6       VertRelAngle  0.369141
#  7       HorzRelAngle  0.379313
#  8           SpinRate  0.384430
#  9           SpinAxis  0.384583
#  10         RelHeight  0.385409
#  11           RelSide  0.385333
#  12         Extension  0.385179
#  13  InducedVertBreak  0.384410
#  14         HorzBreak  0.384722
#  15    PlateLocHeight  0.364271
#  16      PlateLocSide  0.377680
#  17     VertApprAngle  0.382213
#  18     HorzApprAngle  0.381967,
#          feature_name     error
#  0      PitcherThrows  0.428633
#  1         BatterSide  0.428552
#  2               Outs  0.428591
#  3              Balls  0.427546
#  4            Strikes  0.427567
#  5           RelSpeed  0.428978
#  6       VertRelAngle  0.415297
#  7       HorzRelAngle  0.423372
#  8           SpinRate  0.429210
#  9           SpinAxis  0.428876
#  10         RelHeight  0.428648
#  11           RelSide  0.429188
#  12         Extension  0.429115
#  13  InducedVertBreak  0.429208
#  14         HorzBreak  0.428332
#  15    PlateLocHeight  0.405734
#  16      PlateLocSide  0.415886
#  17     VertApprAngle  0.417720
#  18     HorzApprAngle  0.425942)

# %%
FB_feature_importance = FB_feature_error.sort_values(by="error")["feature_name"]
BB_feature_importance = BB_feature_error.sort_values(by="error")["feature_name"]
OFF_feature_importance = OFF_feature_error.sort_values(by="error")["feature_name"]

# %%
FB_x_vars, FB_best_features = best_features(FB_X_train, FB_y_train,FB_feature_importance)
BB_x_vars, BB_best_features = best_features(BB_X_train, BB_y_train,BB_feature_importance)
OFF_x_vars, OFF_best_features = best_features(OFF_X_train, OFF_y_train,OFF_feature_importance)

# %%
feature['FB_x_vars'] = FB_x_vars
feature['FB_error'] = FB_best_features
feature['BB_x_vars'] = BB_x_vars
feature['BB_error'] = BB_best_features
feature['OFF_x_vars'] = OFF_x_vars
feature['OFF_error'] = OFF_best_features

# %%
feature
# Out:
#                                                subset  validation error  \
# 0                                     [VertApprAngle]          0.327775
# 1                       [VertApprAngle, VertRelAngle]          0.317636
# 2       [VertApprAngle, VertRelAngle, PlateLocHeight]          0.311429
# 3   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.303948
# 4   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.299205
# 5   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.295263
# 6   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294464
# 7   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294276
# 8   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.293819
# 9   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291975
# 10  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291572
# 11  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291494
# 12  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290667
# 13  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290608
# 14  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289500
# 15  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289553
# 16  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289467
# 17  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289316
# 18  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289485
#
#                                             FB_x_vars  FB_error  \
# 0                                    [PlateLocHeight]  0.273658
# 1                     [PlateLocHeight, VertApprAngle]  0.269297
# 2       [PlateLocHeight, VertApprAngle, PlateLocSide]  0.261828
# 3   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.257593
# 4   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.255037
# 5   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.252055
# 6   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251601
# 7   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251570
# 8   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.250052
# 9   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.250001
# 10  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.250099
# 11  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248961
# 12  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248903
# 13  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248817
# 14  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246863
# 15  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246862
# 16  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246799
# 17  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246838
# 18  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246873
#
#                                             BB_x_vars  BB_error  \
# 0                                    [PlateLocHeight]  0.364271
# 1                      [PlateLocHeight, VertRelAngle]  0.361345
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]  0.352908
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.348214
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.341742
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.340509
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.337806
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334967
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334906
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334568
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334818
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334756
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334602
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334232
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334259
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334240
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334297
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334486
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334365
#
#                                            OFF_x_vars  OFF_error
# 0                                    [PlateLocHeight]   0.405734
# 1                      [PlateLocHeight, VertRelAngle]   0.405440
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]   0.396119
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.393106
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.387297
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.384590
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.383459
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380320
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380760
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380336
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380472
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380295
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380138
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379943
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379460
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379615
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379471
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379676
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379940

# %%
BB_OFF_train = train[(train['TaggedPitchType'] != 'Fastball') & (train['TaggedPitchType'] != 'Sinker')]
BB_OFF_test = test[(test['TaggedPitchType'] != 'Fastball') & (test['TaggedPitchType'] != 'Sinker')]
comb_X_train,comb_y_train = split(BB_OFF_train)
comb_X_test, comb_y_test = split(BB_OFF_test)

# %%
comb_CV = CV(comb_X_train,comb_y_train)
CV_errors['BB_OFF_CV_error'] = [comb_CV]

# %%
CV_errors
# Out:
#    cv_error  FB_CV_error  BB_CV_error  OFF_CV_error  BB_OFF_CV_error
# 0  0.289485     0.246876     0.334365      0.379937         0.345476

# %% [markdown]
# Here I basically determined that despite the fastball error being lower it wasn't worth how much higher the breaking ball and offspeed error were to use these seperate models to train the data. Like I said at the top, I think one of the main reasons that the error of these pitches seperated is higher is because of how subjective pitch tagging is in college baseball.

# %%
comb_feature_error = feature_error(comb_X_train,comb_y_train)
comb_feature_importance = comb_feature_error.sort_values(by="error")["feature_name"]
comb_x_vars, comb_best_features = best_features(comb_X_train, comb_y_train,comb_feature_importance)
feature['comb_x_vars'] = comb_x_vars
feature['comb_error'] = comb_best_features
feature
# Out:
#                                                subset  validation error  \
# 0                                     [VertApprAngle]          0.327775
# 1                       [VertApprAngle, VertRelAngle]          0.317636
# 2       [VertApprAngle, VertRelAngle, PlateLocHeight]          0.311429
# 3   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.303948
# 4   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.299205
# 5   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.295263
# 6   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294464
# 7   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294276
# 8   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.293819
# 9   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291975
# 10  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291572
# 11  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291494
# 12  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290667
# 13  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290608
# 14  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289500
# 15  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289553
# 16  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289467
# 17  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289316
# 18  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289485
#
#                                             FB_x_vars  FB_error  \
# 0                                    [PlateLocHeight]  0.273658
# 1                     [PlateLocHeight, VertApprAngle]  0.269297
# 2       [PlateLocHeight, VertApprAngle, PlateLocSide]  0.261828
# 3   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.257593
# 4   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.255037
# 5   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.252055
# 6   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251601
# 7   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251570
# 8   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.250052
# 9   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.250001
# 10  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.250099
# 11  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248961
# 12  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248903
# 13  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248817
# 14  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246863
# 15  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246862
# 16  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246799
# 17  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246838
# 18  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246873
#
#                                             BB_x_vars  BB_error  \
# 0                                    [PlateLocHeight]  0.364271
# 1                      [PlateLocHeight, VertRelAngle]  0.361345
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]  0.352908
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.348214
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.341742
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.340509
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.337806
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334967
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334906
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334568
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334818
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334756
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334602
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334232
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334259
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334240
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334297
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334486
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334365
#
#                                            OFF_x_vars  OFF_error  \
# 0                                    [PlateLocHeight]   0.405734
# 1                      [PlateLocHeight, VertRelAngle]   0.405440
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]   0.396119
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.393106
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.387297
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.384590
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.383459
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380320
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380760
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380336
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380472
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380295
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380138
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379943
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379460
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379615
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379471
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379676
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379940
#
#                                           comb_x_vars  comb_error
# 0                                    [PlateLocHeight]    0.376766
# 1                      [PlateLocHeight, VertRelAngle]    0.373140
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]    0.365716
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.360122
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.354479
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.352058
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.350404
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.350187
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.346317
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.346093
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.346255
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345904
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345937
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345962
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.346031
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345548
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345481
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345603
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345476

# %%
feature
# Out:
#                                                subset  validation error  \
# 0                                     [VertApprAngle]          0.327775
# 1                       [VertApprAngle, VertRelAngle]          0.317636
# 2       [VertApprAngle, VertRelAngle, PlateLocHeight]          0.311429
# 3   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.303948
# 4   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.299205
# 5   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.295263
# 6   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294464
# 7   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.294276
# 8   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.293819
# 9   [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291975
# 10  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291572
# 11  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.291494
# 12  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290667
# 13  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.290608
# 14  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289500
# 15  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289553
# 16  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289467
# 17  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289316
# 18  [VertApprAngle, VertRelAngle, PlateLocHeight, ...          0.289485
#
#                                             FB_x_vars  FB_error  \
# 0                                    [PlateLocHeight]  0.273658
# 1                     [PlateLocHeight, VertApprAngle]  0.269297
# 2       [PlateLocHeight, VertApprAngle, PlateLocSide]  0.261828
# 3   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.257593
# 4   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.255037
# 5   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.252055
# 6   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251601
# 7   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.251570
# 8   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.250052
# 9   [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.250001
# 10  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.250099
# 11  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248961
# 12  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248903
# 13  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.248817
# 14  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246863
# 15  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246862
# 16  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246799
# 17  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246838
# 18  [PlateLocHeight, VertApprAngle, PlateLocSide, ...  0.246873
#
#                                             BB_x_vars  BB_error  \
# 0                                    [PlateLocHeight]  0.364271
# 1                      [PlateLocHeight, VertRelAngle]  0.361345
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]  0.352908
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.348214
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.341742
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.340509
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.337806
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334967
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334906
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334568
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334818
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334756
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334602
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334232
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334259
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334240
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334297
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334486
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...  0.334365
#
#                                            OFF_x_vars  OFF_error  \
# 0                                    [PlateLocHeight]   0.405734
# 1                      [PlateLocHeight, VertRelAngle]   0.405440
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]   0.396119
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.393106
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.387297
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.384590
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.383459
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380320
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380760
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380336
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380472
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380295
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.380138
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379943
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379460
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379615
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379471
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379676
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, V...   0.379940
#
#                                           comb_x_vars  comb_error
# 0                                    [PlateLocHeight]    0.376766
# 1                      [PlateLocHeight, VertRelAngle]    0.373140
# 2        [PlateLocHeight, VertRelAngle, PlateLocSide]    0.365716
# 3   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.360122
# 4   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.354479
# 5   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.352058
# 6   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.350404
# 7   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.350187
# 8   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.346317
# 9   [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.346093
# 10  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.346255
# 11  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345904
# 12  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345937
# 13  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345962
# 14  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.346031
# 15  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345548
# 16  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345481
# 17  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345603
# 18  [PlateLocHeight, VertRelAngle, PlateLocSide, H...    0.345476

# %%
pitches_features = feature.sort_values(by='validation error').iloc[0,:]['subset']
pitches_features
# Out:
# array(['VertApprAngle', 'VertRelAngle', 'PlateLocHeight', 'PlateLocSide',
#        'Strikes', 'HorzRelAngle', 'RelSpeed', 'InducedVertBreak',
#        'SpinRate', 'SpinAxis', 'HorzApprAngle', 'HorzBreak', 'Balls',
#        'Outs', 'BatterSide', 'PitcherThrows', 'Extension', 'RelHeight'],
#       dtype=object)

# %%
len(pitches_features)
# Out:
# 18

# %%
# Hyperparameter optimization using Optuna framework
# This systematically searches for the best XGBoost parameters to minimize log loss
def optimze_params(X_train, y_train):
    """
    Optimize XGBoost hyperparameters using Optuna's Tree-structured Parzen Estimator
    
    Parameters optimized:
    - max_depth: Tree depth (complexity control)
    - learning_rate: Step size shrinkage (overfitting control)  
    - n_estimators: Number of boosting rounds
    - colsample_bytree: Feature sampling ratio
    - min_child_weight: Minimum sum of instance weight in child
    
    Args:
        X_train: Training features
        y_train: Training target
        
    Returns:
        Dictionary of optimal hyperparameters
    """
    def objective(trial):
        # Define hyperparameter search space
        param = {
            'objective': 'binary:logistic',
            'eval_metric': 'logloss',
            'max_depth': trial.suggest_int('max_depth', 2, 10),
            'learning_rate': trial.suggest_float('learning_rate', 1e-3, 1e1, log=True),
            'n_estimators': trial.suggest_int('n_estimators', 50, 500),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
            'seed': 69  # Fixed seed for reproducibility
        }
        
        # Train model with current hyperparameters
        model = XGBClassifier(**param, enable_categorical=True)
        model.fit(X_train, y_train)

        # Evaluate on training set (Note: could use validation set for better generalization)
        y_pred = model.predict_proba(X_train)[:, 1]
        return log_loss(y_train, y_pred)
    
    # Create optimization study and run trials
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=50)
    return study.best_params

# %%
new_X_train = X_train[new_X_train_columns]
new_X_test = X_test[new_X_train_columns]

# %%
best_params = optimze_params(new_X_train,y_train)
# Out:
# [I 2024-12-04 12:16:46,443] A new study created in memory with name: no-name-226432d6-0ae1-4c7f-9a9e-7d32655d0757
# [I 2024-12-04 12:17:02,542] Trial 0 finished with value: 0.31265785526445 and parameters: {'max_depth': 2, 'learning_rate': 0.02786157091350208, 'n_estimators': 195, 'colsample_bytree': 0.8975445337494109, 'min_child_weight': 6}. Best is trial 0 with value: 0.31265785526445.
# [I 2024-12-04 12:17:21,553] Trial 1 finished with value: 1.6581614331877133 and parameters: {'max_depth': 4, 'learning_rate': 4.14531562224322, 'n_estimators': 463, 'colsample_bytree': 0.5104961905103984, 'min_child_weight': 9}. Best is trial 0 with value: 0.31265785526445.
# [I 2024-12-04 12:17:42,975] Trial 2 finished with value: 0.29903362965020064 and parameters: {'max_depth': 8, 'learning_rate': 0.016351996758502647, 'n_estimators': 161, 'colsample_bytree': 0.647207750319435, 'min_child_weight': 9}. Best is trial 2 with value: 0.29903362965020064.
# [I 2024-12-04 12:17:51,301] Trial 3 finished with value: 0.3100036350591019 and parameters: {'max_depth': 4, 'learning_rate': 0.026188599942194943, 'n_estimators': 107, 'colsample_bytree': 0.5482560725916865, 'min_child_weight': 8}. Best is trial 2 with value: 0.29903362965020064.
# [I 2024-12-04 12:18:36,527] Trial 4 finished with value: 0.2668445531309345 and parameters: {'max_depth': 7, 'learning_rate': 0.20486574801602095, 'n_estimators': 422, 'colsample_bytree': 0.8854688600552004, 'min_child_weight': 3}. Best is trial 4 with value: 0.2668445531309345.
# [I 2024-12-04 12:19:05,870] Trial 5 finished with value: 0.27319652159857166 and parameters: {'max_depth': 5, 'learning_rate': 1.2067257504963138, 'n_estimators': 394, 'colsample_bytree': 0.7532878627721117, 'min_child_weight': 2}. Best is trial 4 with value: 0.2668445531309345.
# [I 2024-12-04 12:19:38,396] Trial 6 finished with value: 0.27239225169378795 and parameters: {'max_depth': 5, 'learning_rate': 0.8004344409956777, 'n_estimators': 465, 'colsample_bytree': 0.593080391868468, 'min_child_weight': 6}. Best is trial 4 with value: 0.2668445531309345.
# [I 2024-12-04 12:19:45,280] Trial 7 finished with value: 0.30403365047451786 and parameters: {'max_depth': 5, 'learning_rate': 0.04165252622826525, 'n_estimators': 76, 'colsample_bytree': 0.8821148072776146, 'min_child_weight': 3}. Best is trial 4 with value: 0.2668445531309345.
# [I 2024-12-04 12:20:42,173] Trial 8 finished with value: 0.2998761916453614 and parameters: {'max_depth': 10, 'learning_rate': 0.004465071725185991, 'n_estimators': 382, 'colsample_bytree': 0.8334033272177934, 'min_child_weight': 5}. Best is trial 4 with value: 0.2668445531309345.
# [I 2024-12-04 12:20:51,540] Trial 9 finished with value: 0.3118363652880606 and parameters: {'max_depth': 5, 'learning_rate': 0.016144360992778665, 'n_estimators': 109, 'colsample_bytree': 0.7145531882044431, 'min_child_weight': 4}. Best is trial 4 with value: 0.2668445531309345.
# [I 2024-12-04 12:21:21,743] Trial 10 finished with value: 0.2537066278922272 and parameters: {'max_depth': 8, 'learning_rate': 0.2720261344269123, 'n_estimators': 303, 'colsample_bytree': 0.9864810531090497, 'min_child_weight': 1}. Best is trial 10 with value: 0.2537066278922272.
# [I 2024-12-04 12:21:56,332] Trial 11 finished with value: 0.2598138041985961 and parameters: {'max_depth': 8, 'learning_rate': 0.22074748257797297, 'n_estimators': 294, 'colsample_bytree': 0.982405912355279, 'min_child_weight': 1}. Best is trial 10 with value: 0.2537066278922272.
# [I 2024-12-04 12:22:29,767] Trial 12 finished with value: 0.24826799797835597 and parameters: {'max_depth': 9, 'learning_rate': 0.21039993912309948, 'n_estimators': 273, 'colsample_bytree': 0.9999303932301074, 'min_child_weight': 1}. Best is trial 12 with value: 0.24826799797835597.
# [I 2024-12-04 12:23:41,348] Trial 13 finished with value: 0.14193441534914125 and parameters: {'max_depth': 10, 'learning_rate': 0.7689819842885299, 'n_estimators': 292, 'colsample_bytree': 0.9839943896938717, 'min_child_weight': 1}. Best is trial 13 with value: 0.14193441534914125.
# [I 2024-12-04 12:23:51,356] Trial 14 finished with value: 1.889705591404507 and parameters: {'max_depth': 10, 'learning_rate': 6.762670732611867, 'n_estimators': 234, 'colsample_bytree': 0.9503183149934101, 'min_child_weight': 1}. Best is trial 13 with value: 0.14193441534914125.
# [I 2024-12-04 12:24:32,921] Trial 15 finished with value: 0.22003373673353974 and parameters: {'max_depth': 9, 'learning_rate': 1.8121431714221756, 'n_estimators': 336, 'colsample_bytree': 0.8068620643946327, 'min_child_weight': 3}. Best is trial 13 with value: 0.14193441534914125.
# [I 2024-12-04 12:25:18,796] Trial 16 finished with value: 0.10900194459274146 and parameters: {'max_depth': 10, 'learning_rate': 1.651908652707335, 'n_estimators': 346, 'colsample_bytree': 0.7706121033030994, 'min_child_weight': 3}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:25:59,300] Trial 17 finished with value: 0.18364101176305575 and parameters: {'max_depth': 10, 'learning_rate': 0.5430924126709733, 'n_estimators': 349, 'colsample_bytree': 0.7129421761748189, 'min_child_weight': 4}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:26:07,667] Trial 18 finished with value: 2.4522018657780844 and parameters: {'max_depth': 7, 'learning_rate': 2.8857356247370856, 'n_estimators': 240, 'colsample_bytree': 0.7873936978573861, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:26:46,338] Trial 19 finished with value: 0.2697817967542386 and parameters: {'max_depth': 9, 'learning_rate': 0.08842950668864122, 'n_estimators': 326, 'colsample_bytree': 0.6513650994643192, 'min_child_weight': 7}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:26:53,964] Trial 20 finished with value: 2.3305842408765156 and parameters: {'max_depth': 7, 'learning_rate': 8.57700282420624, 'n_estimators': 242, 'colsample_bytree': 0.9187664385047557, 'min_child_weight': 4}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:27:36,513] Trial 21 finished with value: 0.1714956470966076 and parameters: {'max_depth': 10, 'learning_rate': 0.6121961138146117, 'n_estimators': 362, 'colsample_bytree': 0.705462371443004, 'min_child_weight': 4}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:28:18,788] Trial 22 finished with value: 0.15938122447873043 and parameters: {'max_depth': 10, 'learning_rate': 0.5876340575558886, 'n_estimators': 369, 'colsample_bytree': 0.6692103495531428, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:28:44,894] Trial 23 finished with value: 3.849298214988857 and parameters: {'max_depth': 9, 'learning_rate': 2.2271520653015133, 'n_estimators': 428, 'colsample_bytree': 0.6272680792720433, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:29:31,229] Trial 24 finished with value: 0.16503795097879836 and parameters: {'max_depth': 10, 'learning_rate': 0.45858736892058477, 'n_estimators': 405, 'colsample_bytree': 0.8552492175253079, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:30:11,350] Trial 25 finished with value: 0.27093436274239485 and parameters: {'max_depth': 9, 'learning_rate': 0.07688808664835724, 'n_estimators': 307, 'colsample_bytree': 0.6829211328891589, 'min_child_weight': 3}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:31:11,821] Trial 26 finished with value: 0.19195914070904146 and parameters: {'max_depth': 8, 'learning_rate': 1.3144506544935124, 'n_estimators': 493, 'colsample_bytree': 0.757028515794114, 'min_child_weight': 5}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:31:21,576] Trial 27 finished with value: 1.6634774250230724 and parameters: {'max_depth': 10, 'learning_rate': 5.083068240018641, 'n_estimators': 278, 'colsample_bytree': 0.6129658388093128, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:32:01,454] Trial 28 finished with value: 0.1925949525809422 and parameters: {'max_depth': 9, 'learning_rate': 1.0619787550649795, 'n_estimators': 365, 'colsample_bytree': 0.792358826150369, 'min_child_weight': 10}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:32:12,140] Trial 29 finished with value: 0.34095751291334286 and parameters: {'max_depth': 2, 'learning_rate': 0.0018013339876801694, 'n_estimators': 192, 'colsample_bytree': 0.568367756090095, 'min_child_weight': 1}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:32:32,616] Trial 30 finished with value: 0.27405398095000433 and parameters: {'max_depth': 6, 'learning_rate': 0.41022076822757314, 'n_estimators': 262, 'colsample_bytree': 0.9263856567750905, 'min_child_weight': 3}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:33:47,116] Trial 31 finished with value: 0.17964543772128533 and parameters: {'max_depth': 10, 'learning_rate': 0.37517340862094833, 'n_estimators': 416, 'colsample_bytree': 0.8762683729068956, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:33:59,054] Trial 32 finished with value: 1.6982814231377186 and parameters: {'max_depth': 10, 'learning_rate': 3.165201321133899, 'n_estimators': 391, 'colsample_bytree': 0.84598564641427, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:34:36,979] Trial 33 finished with value: 0.2589173409302577 and parameters: {'max_depth': 9, 'learning_rate': 0.1240299537252039, 'n_estimators': 325, 'colsample_bytree': 0.8290693357831043, 'min_child_weight': 1}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:35:18,336] Trial 34 finished with value: 0.20163098879467478 and parameters: {'max_depth': 8, 'learning_rate': 0.9022040919167498, 'n_estimators': 438, 'colsample_bytree': 0.6671389391639938, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:35:39,988] Trial 35 finished with value: 0.29124566436278726 and parameters: {'max_depth': 2, 'learning_rate': 1.5719205705306298, 'n_estimators': 465, 'colsample_bytree': 0.9492454640221262, 'min_child_weight': 3}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:36:30,174] Trial 36 finished with value: 0.24767887806939898 and parameters: {'max_depth': 10, 'learning_rate': 0.1303015227892954, 'n_estimators': 399, 'colsample_bytree': 0.7629686840403825, 'min_child_weight': 7}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:36:51,748] Trial 37 finished with value: 0.2865406464954815 and parameters: {'max_depth': 3, 'learning_rate': 0.5750471415665367, 'n_estimators': 367, 'colsample_bytree': 0.8601942501879585, 'min_child_weight': 5}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:37:17,091] Trial 38 finished with value: 0.24846474822606374 and parameters: {'max_depth': 9, 'learning_rate': 0.327402834917859, 'n_estimators': 209, 'colsample_bytree': 0.730897823373281, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:37:56,350] Trial 39 finished with value: 0.2855932892747614 and parameters: {'max_depth': 6, 'learning_rate': 0.05510644747605628, 'n_estimators': 448, 'colsample_bytree': 0.5123105775346076, 'min_child_weight': 3}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:38:10,979] Trial 40 finished with value: 4.557832383413413 and parameters: {'max_depth': 10, 'learning_rate': 4.725660531147992, 'n_estimators': 489, 'colsample_bytree': 0.9036305876950668, 'min_child_weight': 1}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:38:55,795] Trial 41 finished with value: 0.1659167849541513 and parameters: {'max_depth': 10, 'learning_rate': 0.6289718446619865, 'n_estimators': 365, 'colsample_bytree': 0.6875219385582221, 'min_child_weight': 4}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:39:40,423] Trial 42 finished with value: 0.14386271555832203 and parameters: {'max_depth': 10, 'learning_rate': 0.9155432612337185, 'n_estimators': 344, 'colsample_bytree': 0.685528988116765, 'min_child_weight': 4}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:40:26,565] Trial 43 finished with value: 0.16635308707332272 and parameters: {'max_depth': 9, 'learning_rate': 0.8988505402564454, 'n_estimators': 408, 'colsample_bytree': 0.7371845312404537, 'min_child_weight': 3}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:40:43,085] Trial 44 finished with value: 2.1876980829869592 and parameters: {'max_depth': 10, 'learning_rate': 2.3825909544865524, 'n_estimators': 315, 'colsample_bytree': 0.6260831370758294, 'min_child_weight': 2}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:41:18,509] Trial 45 finished with value: 0.2644432125328962 and parameters: {'max_depth': 8, 'learning_rate': 0.18113613694318625, 'n_estimators': 343, 'colsample_bytree': 0.7767035844830502, 'min_child_weight': 5}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:42:06,310] Trial 46 finished with value: 0.1702835402586568 and parameters: {'max_depth': 9, 'learning_rate': 1.6415309785578243, 'n_estimators': 389, 'colsample_bytree': 0.8120385456859974, 'min_child_weight': 4}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:42:39,738] Trial 47 finished with value: 0.20668390152359725 and parameters: {'max_depth': 10, 'learning_rate': 0.45348951336775883, 'n_estimators': 286, 'colsample_bytree': 0.6539245118793953, 'min_child_weight': 3}. Best is trial 16 with value: 0.10900194459274146.
# [I 2024-12-04 12:44:13,608] Trial 48 finished with value: 0.10438693713690678 and parameters: {'max_depth': 10, 'learning_rate': 0.8970131790904421, 'n_estimators': 378, 'colsample_bytree': 0.6929593912724579, 'min_child_weight': 1}. Best is trial 48 with value: 0.10438693713690678.
# [I 2024-12-04 12:45:05,984] Trial 49 finished with value: 0.28680867184977377 and parameters: {'max_depth': 9, 'learning_rate': 0.015736897304084813, 'n_estimators': 378, 'colsample_bytree': 0.5885568018118561, 'min_child_weight': 1}. Best is trial 48 with value: 0.10438693713690678.

# %%
# Final model training and prediction function
# Uses optimized hyperparameters to train the final model and generate predictions
def create_model(X_train, y_train, X_test, param):
    """
    Train final XGBoost model with optimized parameters and generate predictions
    
    Args:
        X_train: Training features
        y_train: Training target
        X_test: Test features
        param: Optimized hyperparameters from Optuna
        
    Returns:
        y_pred: Predicted probabilities for test set (xWhiff values)
    """
    # Initialize model with optimal parameters
    model = XGBClassifier(**param, enable_categorical=True)
    
    # Train on full training set
    model.fit(X_train, y_train)

    # Generate probability predictions (xWhiff scores)
    y_pred = model.predict_proba(X_test)[:, 1]  # Probability of whiff (class 1)
    return y_pred

# %%
# Generate xWhiff predictions for 2024 test data
# Apply the optimized model to create expected whiff probability for each pitch
xwhiff = create_model(new_X_train, y_train, new_X_test, best_params)
test['xwhiff'] = xwhiff

print(f"xWhiff predictions generated for {len(test)} pitches")
print(f"Mean xWhiff: {test['xwhiff'].mean():.3f}")
print(f"xWhiff range: {test['xwhiff'].min():.3f} to {test['xwhiff'].max():.3f}")

# %%
# Display the final dataset with xWhiff predictions
# This shows the original pitch data enhanced with expected whiff probabilities
test
# Out:
#         PitcherThrows BatterSide  Outs  Balls  Strikes TaggedPitchType  \
# 0               Right      Right     0      0        0          Slider
# 1               Right      Right     0      1        0        Fastball
# 2               Right      Right     0      1        1        Fastball
# 3               Right      Right     0      1        2          Slider
# 4               Right      Right     0      1        2          Slider
# ...               ...        ...   ...    ...      ...             ...
# 1299541         Right       Left     1      0        2        Fastball
# 1299542         Right      Right     2      0        0        Fastball
# 1299543         Right      Right     2      0        1        Fastball
# 1299544         Right      Right     2      0        2        Fastball
# 1299545         Right      Right     2      1        2          Slider
#
#                     PitchCall  RelSpeed  VertRelAngle  HorzRelAngle  ...  \
# 0                  BallCalled  86.34831     -5.087035     -0.556059  ...
# 1                StrikeCalled  94.49974     -3.133086     -0.492520  ...
# 2        FoulBallNotFieldable  94.81021     -3.910073     -1.135525  ...
# 3        FoulBallNotFieldable  86.30865     -1.385858     -0.791508  ...
# 4                  BallCalled  87.45870     -4.605749     -1.323250  ...
# ...                       ...       ...           ...           ...  ...
# 1299541        StrikeSwinging  92.18631      0.167760     -2.363777  ...
# 1299542          StrikeCalled  92.64280     -0.263162     -3.510955  ...
# 1299543        StrikeSwinging  93.60782     -0.195835     -2.925634  ...
# 1299544            BallCalled  92.70635      1.555863     -3.913135  ...
# 1299545        StrikeSwinging  78.95801      1.401154     -0.864378  ...
#
#          InducedVertBreak  HorzBreak  PlateLocHeight  PlateLocSide  \
# 0                -1.26150   -6.71201        -1.24052      -0.79734
# 1                20.20828    3.49654         3.00046       0.29788
# 2                22.06875   -0.43740         2.48669      -0.87744
# 3                 2.34610   -6.38485         2.69703      -1.15108
# 4                 0.27646   -4.37162        -0.43496      -1.44974
# ...                   ...        ...             ...           ...
# 1299541          12.64422   18.25938         3.18957       0.77831
# 1299542          15.40280   13.05642         3.09837      -0.84427
# 1299543          17.26068   10.25316         3.60768      -0.76626
# 1299544          16.00694   10.33784         4.86704      -1.41462
# 1299545         -12.73579  -17.86462         1.23877      -0.92484
#
#          VertApprAngle  HorzApprAngle     PitcherId  whiff  count  \
# 0           -12.231122      -1.751516  1.000234e+09      0    0-0
# 1            -5.365324       0.134391  1.000234e+09      0    1-0
# 2            -5.815582      -1.213668  1.000234e+09      0    1-1
# 3            -7.862841      -1.929632  1.000234e+09      0    1-2
# 4           -11.264591      -2.102031  1.000234e+09      0    1-2
# ...                ...            ...           ...    ...    ...
# 1299541      -3.753137       0.867156  6.945510e+05      1    0-2
# 1299542      -3.653929      -1.209960  6.945510e+05      0    0-0
# 1299543      -3.090463      -1.109277  6.945510e+05      1    0-1
# 1299544      -1.669483      -2.081033  6.945510e+05      0    0-2
# 1299545      -9.377512      -4.014747  6.945510e+05      1    1-2
#
#                xwhiff
# 0        6.303733e-05
# 1        1.164470e-01
# 2        2.141389e-03
# 3        8.039500e-05
# 4        3.355367e-06
# ...               ...
# 1299541  1.518780e-02
# 1299542  5.372665e-02
# 1299543  6.737081e-03
# 1299544  8.121342e-08
# 1299545  9.421811e-01
#
# [1299546 rows x 25 columns]

# %%
# Export the enhanced dataset for use in inference and analysis
# This file contains all original features plus the new xWhiff metric for further study
test.to_csv('./whiff_csvs/2024_xwhiff_college.csv', index=False)

print("Dataset exported successfully!")
print("Ready for inference analysis and pitch tunneling studies.")
